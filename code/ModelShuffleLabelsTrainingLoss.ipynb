# %% [markdown]
# # Reviewer request - train model using shuffled data lables
#
# #### Response: Not possible. Model does not train.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import multiprocessing as mp
import scipy.stats as stats
import os
os.environ['OMP_NUM_THREADS'] = str(1)
import statsmodels.sandbox.stats.multicomp as mc
import seaborn as sns
import h5py
import tools
from importlib import reload
import nibabel as nib
import pathlib

sns.set_style("white")
plt.rcParams["font.family"] = "FreeSans"

# %% [markdown]
# # Load in training loss for regular training and shuffled training labels

# %%
regular_training = np.loadtxt('ANN1280_HiddenLayerRSM_NoDynamics_trainingloss.csv')
shuffled_training = np.loadtxt('ANN1280_HiddenLayerRSM_NoDynamics_ShuffledLabels_trainingloss.csv')

# %%
plt.figure(figsize=(3,3))
plt.title('Learning dynamics \n shuffled vs. unshuffled labels',fontsize=12)
plt.plot(regular_training,linewidth=3,label='Unshuffled')
plt.plot(shuffled_training,linewidth=3,label='Shuffled')
plt.xlabel('Epochs',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc=1)
plt.tight_layout()
# plt.savefig('Model_ShuffleVsUnshuffledLearningDynamics.png',dpi=300)
