# %% [markdown]
# # Cross-subject decoding Motor responses
# ### (LINDEX v. LMID and RINDEX v. RMID)
#
# #### RH denotes right hand (left hemisphere); LH denotes left hand (right hemisphere)
#
# #### Takuya Ito
# #### 08/18/2020

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import multiprocessing as mp
import scipy.stats as stats
import os
os.environ['OMP_NUM_THREADS'] = str(1)
import statsmodels.sandbox.stats.multicomp as mc
import seaborn as sns
import h5py
import tools
from importlib import reload
import nibabel as nib
import pathlib

sns.set_style("whitegrid")
plt.rcParams["font.family"] = "FreeSans"

# %% [markdown]
# ## 0.1 Load data

# %%
# Excluding 084
subjNums = ['013','014','016','017','018','021','023','024','026','027','028','030','031','032','033',
            '034','035','037','038','039','040','041','042','043','045','046','047','048','049','050',
            '053','055','056','057','058','062','063','066','067','068','069','070','072','074','075',
            '076','077','081','085','086','087','088','090','092','093','094','095','097','098','099',
            '101','102','103','104','105','106','108','109','110','111','112','114','115','117','119',
            '120','121','122','123','124','125','126','127','128','129','130','131','132','134','135',
            '136','137','138','139','140','141']



projectdir = '/home/ti61/f_mc1689_1/SRActFlow/'

# Using final partition
networkdef = np.loadtxt(projectdir + 'data/network_partition.txt')
networkorder = np.asarray(sorted(range(len(networkdef)), key=lambda k: networkdef[k]))
networkorder.shape = (len(networkorder),1)
# network mappings for final partition set
networkmappings = {'fpn':7, 'vis1':1, 'vis2':2, 'smn':3, 'aud':8, 'lan':6, 'dan':5, 'con':4, 'dmn':9, 
                   'pmulti':10, 'none1':11, 'none2':12}
networks = networkmappings.keys()

xticks = {}
reorderednetworkaffil = networkdef[networkorder]
for net in networks:
    netNum = networkmappings[net]
    netind = np.where(reorderednetworkaffil==netNum)[0]
    tick = np.max(netind)
    xticks[tick] = net

## General parameters/variables
nParcels = 360
nSubjs = len(subjNums)

glasserfile2 = projectdir + 'data/Q1-Q6_RelatedParcellation210.LR.CorticalAreas_dil_Colors.32k_fs_RL.dlabel.nii'
glasser2 = nib.load(glasserfile2).get_data()
glasser2 = np.squeeze(glasser2)

sortednets = np.sort(list(xticks.keys()))
orderednetworks = []
for net in sortednets: orderednetworks.append(xticks[net])
    
networkpalette = ['royalblue','slateblue','paleturquoise','darkorchid','limegreen',
                  'lightseagreen','yellow','orchid','r','peru','orange','olivedrab']
networkpalette = np.asarray(networkpalette)

OrderedNetworks = ['VIS1','VIS2','SMN','CON','DAN','LAN','FPN','AUD','DMN','PMM','VMM','ORA']

# %%
# gsr = True
nResponses = 2
data_task_rh = np.zeros((len(glasser2),nResponses,len(subjNums)))
data_task_lh = np.zeros((len(glasser2),nResponses,len(subjNums)))

scount = 0
for subj in subjNums:
    data_task_rh[:,:,scount] = tools.loadMotorResponses(subj,hand='Right')
    data_task_lh[:,:,scount] = tools.loadMotorResponses(subj,hand='Left')
    scount += 1

# %% [markdown]
# #### Identify target vertices

# %%
tmp = np.squeeze(nib.load(projectdir + 'data/results/GroupfMRI/MotorRegionsMasksPerSubj/sractflow_smn_outputRH_mask.dscalar.nii').get_data())
targetmask_rh_ind = np.where(tmp==True)[0]

tmp = np.squeeze(nib.load(projectdir + 'data/results/GroupfMRI/MotorRegionsMasksPerSubj/sractflow_smn_outputLH_mask.dscalar.nii').get_data())
targetmask_lh_ind = np.where(tmp==True)[0]

# %% [markdown]
# ## 1.1 Run across subject decoding on hand-specific motor responses

# %%
tools = reload(tools)

subjarray = np.hstack((np.arange(len(subjNums)),np.arange(len(subjNums))))
# same for both LH and RH, since mid will be hstacked on ind
labels = np.hstack((np.repeat(1,len(subjNums)),np.repeat(2,len(subjNums))))

svmmat_rh = np.vstack((data_task_rh[targetmask_rh_ind,0,:].T,data_task_rh[targetmask_rh_ind,1,:].T))
svmmat_lh = np.vstack((data_task_lh[targetmask_lh_ind,0,:].T,data_task_lh[targetmask_lh_ind,1,:].T))


#### Now run decoding accuracies (1000 times, with bootstrapping to obtain CIs)
nbootstraps = 1000
for i in range(nbootstraps):
    decoding_rh, rmatch_rh, rmismatch_rh, tmp = tools.randomSplitLOOBaselineCV(1,svmmat_rh,labels,subjarray)
    decoding_lh, rmatch_lh, rmismatch_lh, tmp = tools.randomSplitLOOBaselineCV(1,svmmat_lh,labels,subjarray)
    
    ##### Save out and append file
    # Open/create file
    pathlib.Path(projectdir + 'data/results/MAIN/srModelPredictionAccuracies/test').mkdir(parents=True,exist_ok=True)
    file_rh = open(projectdir + 'data/results/MAIN/srModelPredictionAccuracies/BaselineMotorDecoding/RH_decoding.txt',"a+")
    file_lh = open(projectdir + 'data/results/MAIN/srModelPredictionAccuracies/BaselineMotorDecoding/LH_decoding.txt',"a+")
    # Write out to file
    print(np.mean(decoding_rh),file=file_rh)
    print(np.mean(decoding_lh),file=file_lh)
    # Close file
    file_rh.close()
    file_lh.close()

    if i%25==0:
        print('Permutation', i)
        print('\tDecoding accuracy RH:', np.mean(decoding_rh), '| R-match:', np.mean(rmatch_rh), '| R-mismatch:', np.mean(rmismatch_rh))
        print('\tDecoding accuracy LH:', np.mean(decoding_lh), '| R-match:', np.mean(rmatch_lh), '| R-mismatch:', np.mean(rmismatch_lh))
# Out:
# Permutation 0
# 	Decoding accuracy RH: 0.7708333333333334 | R-match: 0.08359707389712172 | R-mismatch: -0.08359707389712168
# 	Decoding accuracy LH: 0.8854166666666666 | R-match: 0.10892391154286311 | R-mismatch: -0.10892391154286311
# Permutation 25
# 	Decoding accuracy RH: 0.8333333333333334 | R-match: 0.09992514181303169 | R-mismatch: -0.09992514181303164
# 	Decoding accuracy LH: 0.8854166666666666 | R-match: 0.12104601306937202 | R-mismatch: -0.12104601306937206
# Permutation 50
# 	Decoding accuracy RH: 0.84375 | R-match: 0.0931775251657434 | R-mismatch: -0.09317752516574351
# 	Decoding accuracy LH: 0.9166666666666666 | R-match: 0.12343126363340114 | R-mismatch: -0.12343126363340118
# Permutation 75
# 	Decoding accuracy RH: 0.8541666666666666 | R-match: 0.09009800172259592 | R-mismatch: -0.0900980017225959
# 	Decoding accuracy LH: 0.9270833333333334 | R-match: 0.13713544358375016 | R-mismatch: -0.1371354435837501
# Permutation 100
# 	Decoding accuracy RH: 0.8229166666666666 | R-match: 0.07349825084807816 | R-mismatch: -0.07349825084807815
# 	Decoding accuracy LH: 0.90625 | R-match: 0.13838306225176678 | R-mismatch: -0.13838306225176672
# Permutation 125
# 	Decoding accuracy RH: 0.8125 | R-match: 0.08913943508796995 | R-mismatch: -0.08913943508796994
# 	Decoding accuracy LH: 0.8645833333333334 | R-match: 0.11698443379333628 | R-mismatch: -0.11698443379333621
# Permutation 150
# 	Decoding accuracy RH: 0.8229166666666666 | R-match: 0.0754986302406712 | R-mismatch: -0.07549863024067119
# 	Decoding accuracy LH: 0.9583333333333334 | R-match: 0.149344143746765 | R-mismatch: -0.14934414374676508
# Permutation 175
# 	Decoding accuracy RH: 0.8229166666666666 | R-match: 0.10542819794471447 | R-mismatch: -0.10542819794471454
# 	Decoding accuracy LH: 0.8229166666666666 | R-match: 0.10689438033787473 | R-mismatch: -0.10689438033787461
# Permutation 200
# 	Decoding accuracy RH: 0.8229166666666666 | R-match: 0.10659237392042224 | R-mismatch: -0.10659237392042224
# 	Decoding accuracy LH: 0.9166666666666666 | R-match: 0.12856111349158353 | R-mismatch: -0.12856111349158356
# Permutation 225
# 	Decoding accuracy RH: 0.84375 | R-match: 0.0980497484110247 | R-mismatch: -0.0980497484110248
# 	Decoding accuracy LH: 0.8854166666666666 | R-match: 0.11889955535168051 | R-mismatch: -0.11889955535168051
# Permutation 250
# 	Decoding accuracy RH: 0.8854166666666666 | R-match: 0.11199574312353866 | R-mismatch: -0.11199574312353872
# 	Decoding accuracy LH: 0.8645833333333334 | R-match: 0.11361997984687111 | R-mismatch: -0.11361997984687115
# Permutation 275
# 	Decoding accuracy RH: 0.8229166666666666 | R-match: 0.08946312464144558 | R-mismatch: -0.08946312464144561
# 	Decoding accuracy LH: 0.9583333333333334 | R-match: 0.13225099584275313 | R-mismatch: -0.1322509958427531
# Permutation 300
# 	Decoding accuracy RH: 0.7604166666666666 | R-match: 0.06548497276664104 | R-mismatch: -0.06548497276664104
# 	Decoding accuracy LH: 0.8541666666666666 | R-match: 0.11819814063935158 | R-mismatch: -0.11819814063935156
# Permutation 325
# 	Decoding accuracy RH: 0.8333333333333334 | R-match: 0.10178648917517137 | R-mismatch: -0.1017864891751713
# 	Decoding accuracy LH: 0.8854166666666666 | R-match: 0.12021300666415811 | R-mismatch: -0.12021300666415814
# Permutation 350
# 	Decoding accuracy RH: 0.84375 | R-match: 0.1018927551478586 | R-mismatch: -0.10189275514785862
# 	Decoding accuracy LH: 0.9166666666666666 | R-match: 0.11673149853882332 | R-mismatch: -0.11673149853882331
# Permutation 375
# 	Decoding accuracy RH: 0.8541666666666666 | R-match: 0.09623047468204583 | R-mismatch: -0.0962304746820458
# 	Decoding accuracy LH: 0.9166666666666666 | R-match: 0.1433100822637456 | R-mismatch: -0.14331008226374556
# Permutation 400
# 	Decoding accuracy RH: 0.8125 | R-match: 0.09449736458088848 | R-mismatch: -0.0944973645808886
# 	Decoding accuracy LH: 0.9270833333333334 | R-match: 0.13257311771260985 | R-mismatch: -0.1325731177126098
# Permutation 425
# 	Decoding accuracy RH: 0.7916666666666666 | R-match: 0.07997178738658173 | R-mismatch: -0.07997178738658163
# 	Decoding accuracy LH: 0.9270833333333334 | R-match: 0.13815380390169726 | R-mismatch: -0.1381538039016973
# Permutation 450
# 	Decoding accuracy RH: 0.8645833333333334 | R-match: 0.09651715474016649 | R-mismatch: -0.09651715474016646
# 	Decoding accuracy LH: 0.9166666666666666 | R-match: 0.12589678200164042 | R-mismatch: -0.12589678200164042
# Permutation 475
# 	Decoding accuracy RH: 0.8333333333333334 | R-match: 0.08737204069256754 | R-mismatch: -0.08737204069256758
# 	Decoding accuracy LH: 0.9270833333333334 | R-match: 0.1386585638061215 | R-mismatch: -0.13865856380612143
# Permutation 500
# 	Decoding accuracy RH: 0.7604166666666666 | R-match: 0.0772924159779183 | R-mismatch: -0.07729241597791835
# 	Decoding accuracy LH: 0.8333333333333334 | R-match: 0.1214645134927837 | R-mismatch: -0.12146451349278375
# Permutation 525
# 	Decoding accuracy RH: 0.8541666666666666 | R-match: 0.09975550432636837 | R-mismatch: -0.09975550432636841
# 	Decoding accuracy LH: 0.90625 | R-match: 0.11386784757503006 | R-mismatch: -0.11386784757503014
# Permutation 550
# 	Decoding accuracy RH: 0.8125 | R-match: 0.09832819873429643 | R-mismatch: -0.09832819873429628
# 	Decoding accuracy LH: 0.9375 | R-match: 0.14065454724495705 | R-mismatch: -0.14065454724495707
# Permutation 575
# 	Decoding accuracy RH: 0.7604166666666666 | R-match: 0.09357721650506118 | R-mismatch: -0.09357721650506119
# 	Decoding accuracy LH: 0.9791666666666666 | R-match: 0.12109569476448147 | R-mismatch: -0.12109569476448145
# Permutation 600
# 	Decoding accuracy RH: 0.8541666666666666 | R-match: 0.09275393826511298 | R-mismatch: -0.09275393826511301
# 	Decoding accuracy LH: 0.90625 | R-match: 0.12878244905370761 | R-mismatch: -0.12878244905370753
# Permutation 625
# 	Decoding accuracy RH: 0.8020833333333334 | R-match: 0.0872669436847731 | R-mismatch: -0.0872669436847731
# 	Decoding accuracy LH: 0.8958333333333334 | R-match: 0.1141305709360974 | R-mismatch: -0.11413057093609742
# Permutation 650
# 	Decoding accuracy RH: 0.8229166666666666 | R-match: 0.07838815480555772 | R-mismatch: -0.0783881548055578
# 	Decoding accuracy LH: 0.9375 | R-match: 0.13662603246257957 | R-mismatch: -0.13662603246257954
# Permutation 675
# 	Decoding accuracy RH: 0.84375 | R-match: 0.08311446240498567 | R-mismatch: -0.08311446240498568
# 	Decoding accuracy LH: 0.9479166666666666 | R-match: 0.12364822906219242 | R-mismatch: -0.1236482290621924
# Permutation 700
# 	Decoding accuracy RH: 0.8020833333333334 | R-match: 0.0885452773715123 | R-mismatch: -0.08854527737151241
# 	Decoding accuracy LH: 0.8854166666666666 | R-match: 0.11513668370673903 | R-mismatch: -0.11513668370673913
# Permutation 725
# 	Decoding accuracy RH: 0.7916666666666666 | R-match: 0.08325593898997917 | R-mismatch: -0.08325593898997923
# 	Decoding accuracy LH: 0.875 | R-match: 0.1166473062371184 | R-mismatch: -0.11664730623711837
# Permutation 750
# 	Decoding accuracy RH: 0.8541666666666666 | R-match: 0.08938663794601158 | R-mismatch: -0.08938663794601165
# 	Decoding accuracy LH: 0.8958333333333334 | R-match: 0.11383508098382607 | R-mismatch: -0.11383508098382598
# Permutation 775
# 	Decoding accuracy RH: 0.8333333333333334 | R-match: 0.09448144778411556 | R-mismatch: -0.09448144778411564
# 	Decoding accuracy LH: 0.90625 | R-match: 0.12151435190894423 | R-mismatch: -0.12151435190894422
# Permutation 800
# 	Decoding accuracy RH: 0.8541666666666666 | R-match: 0.09090868801149492 | R-mismatch: -0.09090868801149486
# 	Decoding accuracy LH: 0.84375 | R-match: 0.09948262134285407 | R-mismatch: -0.09948262134285411
# Permutation 825
# 	Decoding accuracy RH: 0.8333333333333334 | R-match: 0.08516548131694414 | R-mismatch: -0.08516548131694408
# 	Decoding accuracy LH: 0.8854166666666666 | R-match: 0.14201334695655024 | R-mismatch: -0.1420133469565503
# Permutation 850
# 	Decoding accuracy RH: 0.7291666666666666 | R-match: 0.07113177092661983 | R-mismatch: -0.07113177092661982
# 	Decoding accuracy LH: 0.90625 | R-match: 0.13973605872755776 | R-mismatch: -0.1397360587275578
# Permutation 875
# 	Decoding accuracy RH: 0.8541666666666666 | R-match: 0.09127408206098513 | R-mismatch: -0.09127408206098525
# 	Decoding accuracy LH: 0.9166666666666666 | R-match: 0.10121159558730293 | R-mismatch: -0.10121159558730293
# Permutation 900
# 	Decoding accuracy RH: 0.8333333333333334 | R-match: 0.09717671347566 | R-mismatch: -0.09717671347566
# 	Decoding accuracy LH: 0.9166666666666666 | R-match: 0.11870428295379097 | R-mismatch: -0.11870428295379094
# Permutation 925
# 	Decoding accuracy RH: 0.8333333333333334 | R-match: 0.10970796108729146 | R-mismatch: -0.10970796108729149
# 	Decoding accuracy LH: 0.8958333333333334 | R-match: 0.12204991608330111 | R-mismatch: -0.12204991608330111
# Permutation 950
# 	Decoding accuracy RH: 0.8958333333333334 | R-match: 0.10310494462627288 | R-mismatch: -0.10310494462627295
# 	Decoding accuracy LH: 0.8958333333333334 | R-match: 0.13185125850710608 | R-mismatch: -0.13185125850710602
# Permutation 975
# 	Decoding accuracy RH: 0.7916666666666666 | R-match: 0.10863381669748039 | R-mismatch: -0.10863381669748036
# 	Decoding accuracy LH: 0.8958333333333334 | R-match: 0.13054864320665324 | R-mismatch: -0.13054864320665321

# %% [markdown]
# ## 1.1 Permutation testing - Run across subject decoding on hand-specific motor responses, shuffled labels

# %%
tools = reload(tools)

subjarray = np.hstack((np.arange(len(subjNums)),np.arange(len(subjNums))))
# same for both LH and RH, since mid will be hstacked on ind
labels = np.hstack((np.repeat(1,len(subjNums)),np.repeat(2,len(subjNums))))

svmmat_rh = np.vstack((data_task_rh[targetmask_rh_ind,0,:].T,data_task_rh[targetmask_rh_ind,1,:].T))
svmmat_lh = np.vstack((data_task_lh[targetmask_lh_ind,0,:].T,data_task_lh[targetmask_lh_ind,1,:].T))


#### Now run decoding accuracies (1000 times, with bootstrapping to obtain CIs)
nbootstraps = 1000
for i in range(nbootstraps):
    decoding_rh, rmatch_rh, rmismatch_rh, tmp = tools.randomSplitLOOBaselineCV(1,svmmat_rh,labels,subjarray,permutation=True)
    decoding_lh, rmatch_lh, rmismatch_lh, tmp = tools.randomSplitLOOBaselineCV(1,svmmat_lh,labels,subjarray,permutation=True)
    
    ##### Save out and append file
    # Open/create file
    file_rh = open(projectdir + 'data/results/MAIN/srModelPredictionAccuracies/BaselineMotorDecoding/RH_null_decoding.txt',"a+")
    file_lh = open(projectdir + 'data/results/MAIN/srModelPredictionAccuracies/BaselineMotorDecoding/LH_null_decoding.txt',"a+")
    # Write out to file
    print(np.mean(decoding_rh),file=file_rh)
    print(np.mean(decoding_lh),file=file_lh)
    # Close file
    file_rh.close()
    file_lh.close()

    if i%25==0:
        print('Permutation', i)
        print('\tDecoding accuracy RH:', np.mean(decoding_rh), '| R-match:', np.mean(rmatch_rh), '| R-mismatch:', np.mean(rmismatch_rh))
        print('\tDecoding accuracy LH:', np.mean(decoding_lh), '| R-match:', np.mean(rmatch_lh), '| R-mismatch:', np.mean(rmismatch_lh))
# Out:
# Permutation 0
# 	Decoding accuracy RH: 0.4791666666666667 | R-match: 0.002671307272009659 | R-mismatch: -0.002671307272009749
# 	Decoding accuracy LH: 0.5104166666666666 | R-match: 0.017101517014077697 | R-mismatch: -0.017101517014077642
# Permutation 25
# 	Decoding accuracy RH: 0.4791666666666667 | R-match: -0.000582831269289002 | R-mismatch: 0.0005828312692890842
# 	Decoding accuracy LH: 0.5 | R-match: 0.00035018318636792153 | R-mismatch: -0.00035018318636788917
# Permutation 50
# 	Decoding accuracy RH: 0.4166666666666667 | R-match: 0.0006280995325208786 | R-mismatch: -0.0006280995325209328
# 	Decoding accuracy LH: 0.5208333333333334 | R-match: -0.008034030838194936 | R-mismatch: 0.008034030838194896
# Permutation 75
# 	Decoding accuracy RH: 0.3958333333333333 | R-match: -0.010292512759506106 | R-mismatch: 0.010292512759506019
# 	Decoding accuracy LH: 0.4479166666666667 | R-match: -0.0009143368271515261 | R-mismatch: 0.0009143368271514908
# Permutation 100
# 	Decoding accuracy RH: 0.5416666666666666 | R-match: -0.006949366582674698 | R-mismatch: 0.006949366582674733
# 	Decoding accuracy LH: 0.5416666666666666 | R-match: 0.009324340365639998 | R-mismatch: -0.009324340365639963
# Permutation 125
# 	Decoding accuracy RH: 0.5 | R-match: -0.00044821780445366736 | R-mismatch: 0.0004482178044535624
# 	Decoding accuracy LH: 0.4375 | R-match: -0.012676148592837999 | R-mismatch: 0.01267614859283793
# Permutation 150
# 	Decoding accuracy RH: 0.5 | R-match: -0.002886820497875101 | R-mismatch: 0.0028868204978751625
# 	Decoding accuracy LH: 0.5625 | R-match: -0.0044910698120107315 | R-mismatch: 0.004491069812010729
# Permutation 175
# 	Decoding accuracy RH: 0.4479166666666667 | R-match: -0.0023572931446305804 | R-mismatch: 0.002357293144630626
# 	Decoding accuracy LH: 0.4895833333333333 | R-match: 0.0038832032212905705 | R-mismatch: -0.003883203221290593
# Permutation 200
# 	Decoding accuracy RH: 0.4479166666666667 | R-match: -0.004590238542683956 | R-mismatch: 0.004590238542684048
# 	Decoding accuracy LH: 0.5729166666666666 | R-match: 0.0037732675979826615 | R-mismatch: -0.0037732675979825422
# Permutation 225
# 	Decoding accuracy RH: 0.53125 | R-match: -0.0034605254460323073 | R-mismatch: 0.003460525446032335
# 	Decoding accuracy LH: 0.5625 | R-match: 0.010005997278761105 | R-mismatch: -0.010005997278761045
# Permutation 250
# 	Decoding accuracy RH: 0.40625 | R-match: -0.00815331774612043 | R-mismatch: 0.008153317746120303
# 	Decoding accuracy LH: 0.5104166666666666 | R-match: -0.006575615685925566 | R-mismatch: 0.006575615685925494
# Permutation 275
# 	Decoding accuracy RH: 0.375 | R-match: -0.015539370523257759 | R-mismatch: 0.015539370523257823
# 	Decoding accuracy LH: 0.53125 | R-match: 0.0009029636522656063 | R-mismatch: -0.0009029636522656202
# Permutation 300
# 	Decoding accuracy RH: 0.5104166666666666 | R-match: -0.005052297142081615 | R-mismatch: 0.005052297142081543
# 	Decoding accuracy LH: 0.5208333333333334 | R-match: 0.0003317488171082986 | R-mismatch: -0.00033174881710820145
# Permutation 325
# 	Decoding accuracy RH: 0.4895833333333333 | R-match: -0.0012734880270626632 | R-mismatch: 0.0012734880270627129
# 	Decoding accuracy LH: 0.375 | R-match: -0.019411987531791294 | R-mismatch: 0.019411987531791297
# Permutation 350
# 	Decoding accuracy RH: 0.53125 | R-match: 0.000537750674627553 | R-mismatch: -0.0005377506746275292
# 	Decoding accuracy LH: 0.5625 | R-match: 0.0026895058891335012 | R-mismatch: -0.0026895058891334834
# Permutation 375
# 	Decoding accuracy RH: 0.4479166666666667 | R-match: -0.00967938298361158 | R-mismatch: 0.009679382983611597
# 	Decoding accuracy LH: 0.4479166666666667 | R-match: -0.00147775771997469 | R-mismatch: 0.001477757719974742
# Permutation 400
# 	Decoding accuracy RH: 0.3645833333333333 | R-match: -0.016882128947932267 | R-mismatch: 0.016882128947932323
# 	Decoding accuracy LH: 0.5104166666666666 | R-match: -0.005982219551584331 | R-mismatch: 0.005982219551584275
# Permutation 425
# 	Decoding accuracy RH: 0.5 | R-match: -0.0036707346369833816 | R-mismatch: 0.003670734636983483
# 	Decoding accuracy LH: 0.5104166666666666 | R-match: 0.006221601325114123 | R-mismatch: -0.006221601325114162
# Permutation 450
# 	Decoding accuracy RH: 0.5625 | R-match: 0.0074633569596802 | R-mismatch: -0.007463356959680217
# 	Decoding accuracy LH: 0.4375 | R-match: -0.009684392167567854 | R-mismatch: 0.009684392167567927
# Permutation 475
# 	Decoding accuracy RH: 0.34375 | R-match: -0.013941412899816779 | R-mismatch: 0.0139414128998167
# 	Decoding accuracy LH: 0.5416666666666666 | R-match: 0.008650673887969449 | R-mismatch: -0.008650673887969492
# Permutation 500
# 	Decoding accuracy RH: 0.5104166666666666 | R-match: 0.005853519595268457 | R-mismatch: -0.005853519595268493
# 	Decoding accuracy LH: 0.4895833333333333 | R-match: 0.003812837613717691 | R-mismatch: -0.0038128376137176573
# Permutation 525
# 	Decoding accuracy RH: 0.5208333333333334 | R-match: -0.0032144650212047273 | R-mismatch: 0.003214465021204713
# 	Decoding accuracy LH: 0.5625 | R-match: 0.0009297816043122212 | R-mismatch: -0.0009297816043121622
# Permutation 550
# 	Decoding accuracy RH: 0.5416666666666666 | R-match: 0.011326560819241424 | R-mismatch: -0.011326560819241493
# 	Decoding accuracy LH: 0.46875 | R-match: -0.007673410057048025 | R-mismatch: 0.0076734100570479856
# Permutation 575
# 	Decoding accuracy RH: 0.5 | R-match: -0.012605013150182115 | R-mismatch: 0.012605013150182148
# 	Decoding accuracy LH: 0.5104166666666666 | R-match: 0.0017438531946067615 | R-mismatch: -0.0017438531946067952
# Permutation 600
# 	Decoding accuracy RH: 0.5104166666666666 | R-match: 0.002117815465379326 | R-mismatch: -0.002117815465379188
# 	Decoding accuracy LH: 0.5104166666666666 | R-match: 2.9866845449799787e-05 | R-mismatch: -2.986684544980846e-05
# Permutation 625
# 	Decoding accuracy RH: 0.59375 | R-match: 0.011490132974258846 | R-mismatch: -0.011490132974258905
# 	Decoding accuracy LH: 0.46875 | R-match: -0.0027638110879430813 | R-mismatch: 0.0027638110879431104
# Permutation 650
# 	Decoding accuracy RH: 0.6145833333333334 | R-match: 0.0083904910170134 | R-mismatch: -0.008390491017013413
# 	Decoding accuracy LH: 0.5 | R-match: -0.00028418383255377253 | R-mismatch: 0.00028418383255368146
# Permutation 675
# 	Decoding accuracy RH: 0.5416666666666666 | R-match: 0.007476320392258402 | R-mismatch: -0.007476320392258423
# 	Decoding accuracy LH: 0.5104166666666666 | R-match: -0.0038565804554546077 | R-mismatch: 0.003856580455454626
# Permutation 700
# 	Decoding accuracy RH: 0.5104166666666666 | R-match: 0.0056107212659471115 | R-mismatch: -0.005610721265947087
# 	Decoding accuracy LH: 0.5416666666666666 | R-match: 0.0013187560023284262 | R-mismatch: -0.0013187560023284561
# Permutation 725
# 	Decoding accuracy RH: 0.5104166666666666 | R-match: -0.0011283168111457691 | R-mismatch: 0.0011283168111457093
# 	Decoding accuracy LH: 0.4479166666666667 | R-match: -0.009029263698013539 | R-mismatch: 0.009029263698013493
# Permutation 750
# 	Decoding accuracy RH: 0.5833333333333334 | R-match: -0.0002516723121199956 | R-mismatch: 0.00025167231212003087
# 	Decoding accuracy LH: 0.4791666666666667 | R-match: -0.0035031384831216324 | R-mismatch: 0.0035031384831216497
# Permutation 775
# 	Decoding accuracy RH: 0.5625 | R-match: 0.009201002827361837 | R-mismatch: -0.00920100282736189
# 	Decoding accuracy LH: 0.46875 | R-match: -0.013461052479392182 | R-mismatch: 0.013461052479392104
# Permutation 800
# 	Decoding accuracy RH: 0.4895833333333333 | R-match: 0.00236940498079643 | R-mismatch: -0.0023694049807963615
# 	Decoding accuracy LH: 0.4583333333333333 | R-match: -0.0049957945884738075 | R-mismatch: 0.00499579458847377
# Permutation 825
# 	Decoding accuracy RH: 0.5 | R-match: -0.008600794065092938 | R-mismatch: 0.008600794065093053
# 	Decoding accuracy LH: 0.5208333333333334 | R-match: 0.003201283004835484 | R-mismatch: -0.003201283004835387
# Permutation 850
# 	Decoding accuracy RH: 0.53125 | R-match: 0.010115228700287112 | R-mismatch: -0.010115228700287108
# 	Decoding accuracy LH: 0.4791666666666667 | R-match: 0.005924144118318618 | R-mismatch: -0.005924144118318588
# Permutation 875
# 	Decoding accuracy RH: 0.5104166666666666 | R-match: -0.003494462086030324 | R-mismatch: 0.003494462086030312
# 	Decoding accuracy LH: 0.4791666666666667 | R-match: 0.00109848439088099 | R-mismatch: -0.001098484390880946
# Permutation 900
# 	Decoding accuracy RH: 0.5208333333333334 | R-match: -0.0016320671166555497 | R-mismatch: 0.0016320671166555366
# 	Decoding accuracy LH: 0.5208333333333334 | R-match: 0.01190345859237948 | R-mismatch: -0.011903458592379465
# Permutation 925
# 	Decoding accuracy RH: 0.53125 | R-match: -0.0042219816627596255 | R-mismatch: 0.004221981662759667
# 	Decoding accuracy LH: 0.46875 | R-match: -0.008531077495289122 | R-mismatch: 0.008531077495289136
# Permutation 950
# 	Decoding accuracy RH: 0.4479166666666667 | R-match: -0.005896451667573732 | R-mismatch: 0.00589645166757383
# 	Decoding accuracy LH: 0.5833333333333334 | R-match: 0.0013874090737446571 | R-mismatch: -0.0013874090737446322
# Permutation 975
# 	Decoding accuracy RH: 0.5416666666666666 | R-match: 0.0040576775828015015 | R-mismatch: -0.004057677582801436
# 	Decoding accuracy LH: 0.46875 | R-match: 0.0008083453185273723 | R-mismatch: -0.0008083453185273393
