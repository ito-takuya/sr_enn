# %% [markdown]
# # Pilot 2 -- Compute the baseline decodability of various input stimuli combinations
# ### Ex: Color stims ([red, red] v. [red, blue] v. [blue, red] v. [blue, blue])
#
# ## Use SVM classifications to input stimuli (both modalities: visual and auditory)
# ## Using Ciric-style postprocessing
#
# ## Takuya Ito
# #### 12/06/2018

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import multiprocessing as mp
import scipy.stats as stats
import nibabel as nib
import os
os.environ['OMP_NUM_THREADS'] = str(1)
import statsmodels.api as sm
import sklearn.svm as svm
import statsmodels.sandbox.stats.multicomp as mc
import sklearn
from sklearn.feature_selection import f_classif
import seaborn as sns
import h5py
os.sys.path.append('glmScripts/')
import taskGLMPipeline as tgp

sns.set_style("whitegrid")
plt.rcParams["font.family"] = "FreeSans"

# %%
# Excluding 084
subjNums = ['013','014','016','017','018','021','023','024','026','027','028','030','031','032','033',
            '034','035','037','038','039','040','041','042','043','045','046','047','048','049','050',
            '053','055','056','057','058','062','063','066','067','068','069','070','072','074','075',
            '076','077','081','085','086','087','088','090','092','093','094','095','097','098','099',
            '101','102','103','104','105','106','108','109','110','111','112','114','115','117','119',
            '120','121','122','123','124','125','126','127','128','129','130','131','132','134','135',
            '136','137','138','139','140','141']



basedir = '/projects3/SRActFlow/'

# Using final partition
networkdef = np.loadtxt('/projects3/NetworkDiversity/data/network_partition.txt')
networkorder = np.asarray(sorted(range(len(networkdef)), key=lambda k: networkdef[k]))
networkorder.shape = (len(networkorder),1)
# network mappings for final partition set
networkmappings = {'fpn':7, 'vis1':1, 'vis2':2, 'smn':3, 'aud':8, 'lan':6, 'dan':5, 'con':4, 'dmn':9, 
                   'pmulti':10, 'none1':11, 'none2':12}
networks = networkmappings.keys()

xticks = {}
reorderednetworkaffil = networkdef[networkorder]
for net in networks:
    netNum = networkmappings[net]
    netind = np.where(reorderednetworkaffil==netNum)[0]
    tick = np.max(netind)
    xticks[tick] = net

## General parameters/variables
nParcels = 360
nSubjs = len(subjNums)

glasserfile2 = '/projects/AnalysisTools/ParcelsGlasser2016/Q1-Q6_RelatedParcellation210.LR.CorticalAreas_dil_Colors.32k_fs_RL.dlabel.nii'
glasser2 = nib.load(glasserfile2).get_data()
glasser2 = np.squeeze(glasser2)

sortednets = np.sort(xticks.keys())
orderednetworks = []
for net in sortednets: orderednetworks.append(xticks[net])
    
networkpalette = ['royalblue','slateblue','paleturquoise','darkorchid','limegreen',
                  'lightseagreen','yellow','orchid','r','peru','orange','olivedrab']
networkpalette = np.asarray(networkpalette)

OrderedNetworks = ['VIS1','VIS2','SMN','CON','DAN','LAN','FPN','AUD','DMN','PMM','VMM','ORA']

# %% [markdown]
# # 0.0 Define functions for loading data

# %%
def loadInputActivity(subj,inputtype):
    x = tgp.loadTaskTiming(subj,'ALL')
    stimIndex = np.asarray(x['stimIndex'])
    ind = np.where(stimIndex==inputtype)[0]+1
    
    datadir = basedir + 'data/postProcessing/hcpPostProcCiric/'
    h5f = h5py.File(datadir + subj + '_glmOutput_data.h5','r')
    data = h5f['taskRegression/ALL_24pXaCompCorXVolterra_taskReg_betas_canonical'][:].copy()
    data = data[:,ind].copy()
    h5f.close()
    return data

# %% [markdown]
# # 0.1 Define functions for motor response decodings

# %%
from scipy.spatial.distance import cdist

def srDecoding(data, inputtype, ncvs=100, nproc=5):
    """
    Run an across-subject classification
    Decode input stimuli (4-way decoding) for each sensory rule type
    Limit to ROIs within either vis or aud network
    """
        
    nstim = 4 # Number of stimuli per stimulus-type
    
    nSubjs = data.shape[2]
#     if inputtype in ['cproColorStim','cproOriStim']:
#         # Visual networks
#         rois = np.where((networkdef==networkmappings['vis1']) | (networkdef==networkmappings['vis2']))[0] 
#         rois = rois + 1
#     elif inputtype in ['cproConstantStim','cproPitchStim']:
#         rois = np.where(networkdef==networkmappings['aud'])[0]
#         rois = rois + 1
    rois = np.arange(nParcels)+1
    netStats = np.zeros((len(rois),nstim*nSubjs))


    nsamples = nSubjs * nstim

    # Label array for supervised learning
    labels = np.tile(range(nstim),nSubjs)
    subjarray = np.repeat(range(nSubjs),nstim)

    # Run SVM classifications on network-level activation patterns across subjects
    roicount = 0
    for roi in rois:
        print 'Computing SVM classification for input stimuli:', inputtype, 'for ROI', roicount, '/', len(rois)
        roi_ind = np.where(glasser2==roi)[0]
        nfeatures = len(roi_ind)
        roi_ind.shape = (len(roi_ind),1)       

        svm_mat = np.zeros((nsamples,roi_ind.shape[0]))
        samplecount = 0
        scount = 0
        for subj in range(len(subjNums)):
            roidata = np.squeeze(data[roi_ind,:,scount])
            svm_mat[samplecount:(samplecount+nstim),:] = roidata.T

            scount += 1
            samplecount += nstim

#             # Spatially demean matrix across features
#             samplemean = np.mean(svm_mat,axis=1)
#             samplemean.shape = (len(samplemean),1)
#             svm_mat = svm_mat - samplemean

        scores = randomSplitLOOBaselineCV(ncvs, svm_mat, labels, subjarray, nproc=nproc)
        netStats[roicount,:] = scores
        roicount += 1


    return netStats

def randomSplitLOOBaselineCV(ncvs, svm_mat, labels, subjarray, nproc=5):
    """
    Runs cross validation for an across-subject SVM analysis
    """
    
    ntasks = len(np.unique(labels))
    nsamples = svm_mat.shape[0]
    nsubjs = nsamples/ntasks

    subjects = np.unique(subjarray)
    indices = np.arange(nsamples)
    
    numsubjs_perfold = 8
    if nsubjs%numsubjs_perfold!=0: 
        raise Exception("Error: Folds don't match number of subjects")
        
    nfolds = nsubjs/numsubjs_perfold
    subj_array_folds = subjarray.copy()
    
    inputs = [] 
    
    for fold in range(nfolds):
        test_subjs = np.random.choice(subj_array_folds,numsubjs_perfold,replace=False)
        train_subjs_all = np.delete(subjects,test_subjs)
        for cv in range(ncvs):
            # Randomly sample half of train set subjects for each cv (CV bootstrapping)
            train_subjs = np.random.choice(train_subjs_all,
                                         int(np.floor(len(train_subjs_all)*(2.0))),
                                         replace=True)

            train_ind = []
            for subj in train_subjs:
                train_ind.extend(np.where(subjarray==subj)[0])

            test_ind = []
            for subj in test_subjs:
                test_ind.extend(np.where(subjarray==subj)[0])
            
            train_ind = np.asarray(train_ind)
            test_ind = np.asarray(test_ind)

            trainset = svm_mat[train_ind,:]
            testset = svm_mat[test_ind,:]

            # Normalize trainset and testset
            mean = np.mean(svm_mat[train_ind,:],axis=0)
            mean.shape = (1,len(mean))
            std = np.std(svm_mat[train_ind,:],axis=0)
            std.shape = (1,len(std))

            trainset = np.divide((trainset - mean),std)
            testset = np.divide((testset - mean),std)

            inputs.append((trainset,testset,labels[train_ind],labels[test_ind]))
        
        subj_array_folds = np.delete(subj_array_folds,test_subjs)
        
    pool = mp.Pool(processes=nproc)
    scores = pool.map_async(_decoding,inputs).get()
    pool.close()
    pool.join()
    
#     subj_acc = np.zeros((len(subjects),))
#     scount = 0
#     i = 0
#     for subj in subjects:
#         subjmean = []
#         for cv in range(ncvs):
#             subjmean.append(scores[i])
#             i += 1
        
#         subj_acc[scount] = np.mean(subjmean)
        
#         scount += 1

#     return subj_acc
    acc = []
    for score in scores:
        acc.extend(score)
    return acc

def _decoding((trainset,testset,trainlabels,testlabels)):

#     clf = sklearn.linear_model.LogisticRegression()
    clf = svm.SVC(C=1.0, kernel='linear')

    clf.fit(trainset,trainlabels)
    predictions = clf.predict(testset)
    acc = predictions==testlabels
#     score = np.mean(acc)
    
    return acc

# %% [markdown]
# # 1.0 Run across subject decoding on RED SR rules
# ### 4-way decoding
# * both red
# * notboth red
# * either red
# * neither red

# %% [markdown]
# ## 1.1 Load data for RED SR integration

# %%
# gsr = True
nStims = 4
data_task = np.zeros((len(glasser2),nStims,len(subjNums)))
sr_rule = 'srRed'

scount = 0
for subj in subjNums:
    data_task[:,:,scount] = loadInputActivity(subj,sr_rule)
    scount += 1

# %%
nproc = 30
ncvs = 1

distances_baseline = srDecoding(data_task, sr_rule, ncvs=ncvs, nproc=nproc)
# Out:
# Computing SVM classification for input stimuli: srRed for ROI 0 / 360
# Computing SVM classification for input stimuli: srRed for ROI 1 / 360
# Computing SVM classification for input stimuli: srRed for ROI 2 / 360
# Computing SVM classification for input stimuli: srRed for ROI 3 / 360
# Computing SVM classification for input stimuli: srRed for ROI 4 / 360
# Computing SVM classification for input stimuli: srRed for ROI 5 / 360
# Computing SVM classification for input stimuli: srRed for ROI 6 / 360
# Computing SVM classification for input stimuli: srRed for ROI 7 / 360
# Computing SVM classification for input stimuli: srRed for ROI 8 / 360
# Computing SVM classification for input stimuli: srRed for ROI 9 / 360
# Computing SVM classification for input stimuli: srRed for ROI 10 / 360
# Computing SVM classification for input stimuli: srRed for ROI 11 / 360
# Computing SVM classification for input stimuli: srRed for ROI 12 / 360
# Computing SVM classification for input stimuli: srRed for ROI 13 / 360
# Computing SVM classification for input stimuli: srRed for ROI 14 / 360
# Computing SVM classification for input stimuli: srRed for ROI 15 / 360
# Computing SVM classification for input stimuli: srRed for ROI 16 / 360
# Computing SVM classification for input stimuli: srRed for ROI 17 / 360
# Computing SVM classification for input stimuli: srRed for ROI 18 / 360
# Computing SVM classification for input stimuli: srRed for ROI 19 / 360
# Computing SVM classification for input stimuli: srRed for ROI 20 / 360
# Computing SVM classification for input stimuli: srRed for ROI 21 / 360
# Computing SVM classification for input stimuli: srRed for ROI 22 / 360
# Computing SVM classification for input stimuli: srRed for ROI 23 / 360
# Computing SVM classification for input stimuli: srRed for ROI 24 / 360
# Computing SVM classification for input stimuli: srRed for ROI 25 / 360
# Computing SVM classification for input stimuli: srRed for ROI 26 / 360
# Computing SVM classification for input stimuli: srRed for ROI 27 / 360
# Computing SVM classification for input stimuli: srRed for ROI 28 / 360
# Computing SVM classification for input stimuli: srRed for ROI 29 / 360
# Computing SVM classification for input stimuli: srRed for ROI 30 / 360
# Computing SVM classification for input stimuli: srRed for ROI 31 / 360
# Computing SVM classification for input stimuli: srRed for ROI 32 / 360
# Computing SVM classification for input stimuli: srRed for ROI 33 / 360
# Computing SVM classification for input stimuli: srRed for ROI 34 / 360
# Computing SVM classification for input stimuli: srRed for ROI 35 / 360
# Computing SVM classification for input stimuli: srRed for ROI 36 / 360
# Computing SVM classification for input stimuli: srRed for ROI 37 / 360
# Computing SVM classification for input stimuli: srRed for ROI 38 / 360
# Computing SVM classification for input stimuli: srRed for ROI 39 / 360
# Computing SVM classification for input stimuli: srRed for ROI 40 / 360
# Computing SVM classification for input stimuli: srRed for ROI 41 / 360
# Computing SVM classification for input stimuli: srRed for ROI 42 / 360
# Computing SVM classification for input stimuli: srRed for ROI 43 / 360
# Computing SVM classification for input stimuli: srRed for ROI 44 / 360
# Computing SVM classification for input stimuli: srRed for ROI 45 / 360
# Computing SVM classification for input stimuli: srRed for ROI 46 / 360
# Computing SVM classification for input stimuli: srRed for ROI 47 / 360
# Computing SVM classification for input stimuli: srRed for ROI 48 / 360
# Computing SVM classification for input stimuli: srRed for ROI 49 / 360
# Computing SVM classification for input stimuli: srRed for ROI 50 / 360
# Computing SVM classification for input stimuli: srRed for ROI 51 / 360
# Computing SVM classification for input stimuli: srRed for ROI 52 / 360
# Computing SVM classification for input stimuli: srRed for ROI 53 / 360
# Computing SVM classification for input stimuli: srRed for ROI 54 / 360
# Computing SVM classification for input stimuli: srRed for ROI 55 / 360
# Computing SVM classification for input stimuli: srRed for ROI 56 / 360
# Computing SVM classification for input stimuli: srRed for ROI 57 / 360
# Computing SVM classification for input stimuli: srRed for ROI 58 / 360
# Computing SVM classification for input stimuli: srRed for ROI 59 / 360
# Computing SVM classification for input stimuli: srRed for ROI 60 / 360
# Computing SVM classification for input stimuli: srRed for ROI 61 / 360
# Computing SVM classification for input stimuli: srRed for ROI 62 / 360
# Computing SVM classification for input stimuli: srRed for ROI 63 / 360
# Computing SVM classification for input stimuli: srRed for ROI 64 / 360
# Computing SVM classification for input stimuli: srRed for ROI 65 / 360
# Computing SVM classification for input stimuli: srRed for ROI 66 / 360
# Computing SVM classification for input stimuli: srRed for ROI 67 / 360
# Computing SVM classification for input stimuli: srRed for ROI 68 / 360
# Computing SVM classification for input stimuli: srRed for ROI 69 / 360
# Computing SVM classification for input stimuli: srRed for ROI 70 / 360
# Computing SVM classification for input stimuli: srRed for ROI 71 / 360
# Computing SVM classification for input stimuli: srRed for ROI 72 / 360
# Computing SVM classification for input stimuli: srRed for ROI 73 / 360
# Computing SVM classification for input stimuli: srRed for ROI 74 / 360
# Computing SVM classification for input stimuli: srRed for ROI 75 / 360
# Computing SVM classification for input stimuli: srRed for ROI 76 / 360
# Computing SVM classification for input stimuli: srRed for ROI 77 / 360
# Computing SVM classification for input stimuli: srRed for ROI 78 / 360
# Computing SVM classification for input stimuli: srRed for ROI 79 / 360
# Computing SVM classification for input stimuli: srRed for ROI 80 / 360
# Computing SVM classification for input stimuli: srRed for ROI 81 / 360
# Computing SVM classification for input stimuli: srRed for ROI 82 / 360
# Computing SVM classification for input stimuli: srRed for ROI 83 / 360
# Computing SVM classification for input stimuli: srRed for ROI 84 / 360
# Computing SVM classification for input stimuli: srRed for ROI 85 / 360
# Computing SVM classification for input stimuli: srRed for ROI 86 / 360
# Computing SVM classification for input stimuli: srRed for ROI 87 / 360
# Computing SVM classification for input stimuli: srRed for ROI 88 / 360
# Computing SVM classification for input stimuli: srRed for ROI 89 / 360
# Computing SVM classification for input stimuli: srRed for ROI 90 / 360
# Computing SVM classification for input stimuli: srRed for ROI 91 / 360
# Computing SVM classification for input stimuli: srRed for ROI 92 / 360
# Computing SVM classification for input stimuli: srRed for ROI 93 / 360
# Computing SVM classification for input stimuli: srRed for ROI 94 / 360
# Computing SVM classification for input stimuli: srRed for ROI 95 / 360
# Computing SVM classification for input stimuli: srRed for ROI 96 / 360
# Computing SVM classification for input stimuli: srRed for ROI 97 / 360
# Computing SVM classification for input stimuli: srRed for ROI 98 / 360
# Computing SVM classification for input stimuli: srRed for ROI 99 / 360
# Computing SVM classification for input stimuli: srRed for ROI 100 / 360
# Computing SVM classification for input stimuli: srRed for ROI 101 / 360
# Computing SVM classification for input stimuli: srRed for ROI 102 / 360
# Computing SVM classification for input stimuli: srRed for ROI 103 / 360
# Computing SVM classification for input stimuli: srRed for ROI 104 / 360
# Computing SVM classification for input stimuli: srRed for ROI 105 / 360
# Computing SVM classification for input stimuli: srRed for ROI 106 / 360
# Computing SVM classification for input stimuli: srRed for ROI 107 / 360
# Computing SVM classification for input stimuli: srRed for ROI 108 / 360
# Computing SVM classification for input stimuli: srRed for ROI 109 / 360
# Computing SVM classification for input stimuli: srRed for ROI 110 / 360
# Computing SVM classification for input stimuli: srRed for ROI 111 / 360
# Computing SVM classification for input stimuli: srRed for ROI 112 / 360
# Computing SVM classification for input stimuli: srRed for ROI 113 / 360
# Computing SVM classification for input stimuli: srRed for ROI 114 / 360
# Computing SVM classification for input stimuli: srRed for ROI 115 / 360
# Computing SVM classification for input stimuli: srRed for ROI 116 / 360
# Computing SVM classification for input stimuli: srRed for ROI 117 / 360
# Computing SVM classification for input stimuli: srRed for ROI 118 / 360
# Computing SVM classification for input stimuli: srRed for ROI 119 / 360
# Computing SVM classification for input stimuli: srRed for ROI 120 / 360
# Computing SVM classification for input stimuli: srRed for ROI 121 / 360
# Computing SVM classification for input stimuli: srRed for ROI 122 / 360
# Computing SVM classification for input stimuli: srRed for ROI 123 / 360
# Computing SVM classification for input stimuli: srRed for ROI 124 / 360
# Computing SVM classification for input stimuli: srRed for ROI 125 / 360
# Computing SVM classification for input stimuli: srRed for ROI 126 / 360
# Computing SVM classification for input stimuli: srRed for ROI 127 / 360
# Computing SVM classification for input stimuli: srRed for ROI 128 / 360
# Computing SVM classification for input stimuli: srRed for ROI 129 / 360
# Computing SVM classification for input stimuli: srRed for ROI 130 / 360
# Computing SVM classification for input stimuli: srRed for ROI 131 / 360
# Computing SVM classification for input stimuli: srRed for ROI 132 / 360
# Computing SVM classification for input stimuli: srRed for ROI 133 / 360
# Computing SVM classification for input stimuli: srRed for ROI 134 / 360
# Computing SVM classification for input stimuli: srRed for ROI 135 / 360
# Computing SVM classification for input stimuli: srRed for ROI 136 / 360
# Computing SVM classification for input stimuli: srRed for ROI 137 / 360
# Computing SVM classification for input stimuli: srRed for ROI 138 / 360
# Computing SVM classification for input stimuli: srRed for ROI 139 / 360
# Computing SVM classification for input stimuli: srRed for ROI 140 / 360
# Computing SVM classification for input stimuli: srRed for ROI 141 / 360
# Computing SVM classification for input stimuli: srRed for ROI 142 / 360
# Computing SVM classification for input stimuli: srRed for ROI 143 / 360
# Computing SVM classification for input stimuli: srRed for ROI 144 / 360
# Computing SVM classification for input stimuli: srRed for ROI 145 / 360
# Computing SVM classification for input stimuli: srRed for ROI 146 / 360
# Computing SVM classification for input stimuli: srRed for ROI 147 / 360
# Computing SVM classification for input stimuli: srRed for ROI 148 / 360
# Computing SVM classification for input stimuli: srRed for ROI 149 / 360
# Computing SVM classification for input stimuli: srRed for ROI 150 / 360
# Computing SVM classification for input stimuli: srRed for ROI 151 / 360
# Computing SVM classification for input stimuli: srRed for ROI 152 / 360
# Computing SVM classification for input stimuli: srRed for ROI 153 / 360
# Computing SVM classification for input stimuli: srRed for ROI 154 / 360
# Computing SVM classification for input stimuli: srRed for ROI 155 / 360
# Computing SVM classification for input stimuli: srRed for ROI 156 / 360
# Computing SVM classification for input stimuli: srRed for ROI 157 / 360
# Computing SVM classification for input stimuli: srRed for ROI 158 / 360
# Computing SVM classification for input stimuli: srRed for ROI 159 / 360
# Computing SVM classification for input stimuli: srRed for ROI 160 / 360
# Computing SVM classification for input stimuli: srRed for ROI 161 / 360
# Computing SVM classification for input stimuli: srRed for ROI 162 / 360
# Computing SVM classification for input stimuli: srRed for ROI 163 / 360
# Computing SVM classification for input stimuli: srRed for ROI 164 / 360
# Computing SVM classification for input stimuli: srRed for ROI 165 / 360
# Computing SVM classification for input stimuli: srRed for ROI 166 / 360
# Computing SVM classification for input stimuli: srRed for ROI 167 / 360
# Computing SVM classification for input stimuli: srRed for ROI 168 / 360
# Computing SVM classification for input stimuli: srRed for ROI 169 / 360
# Computing SVM classification for input stimuli: srRed for ROI 170 / 360
# Computing SVM classification for input stimuli: srRed for ROI 171 / 360
# Computing SVM classification for input stimuli: srRed for ROI 172 / 360
# Computing SVM classification for input stimuli: srRed for ROI 173 / 360
# Computing SVM classification for input stimuli: srRed for ROI 174 / 360
# Computing SVM classification for input stimuli: srRed for ROI 175 / 360
# Computing SVM classification for input stimuli: srRed for ROI 176 / 360
# Computing SVM classification for input stimuli: srRed for ROI 177 / 360
# Computing SVM classification for input stimuli: srRed for ROI 178 / 360
# Computing SVM classification for input stimuli: srRed for ROI 179 / 360
# Computing SVM classification for input stimuli: srRed for ROI 180 / 360
# Computing SVM classification for input stimuli: srRed for ROI 181 / 360
# Computing SVM classification for input stimuli: srRed for ROI 182 / 360
# Computing SVM classification for input stimuli: srRed for ROI 183 / 360
# Computing SVM classification for input stimuli: srRed for ROI 184 / 360
# Computing SVM classification for input stimuli: srRed for ROI 185 / 360
# Computing SVM classification for input stimuli: srRed for ROI 186 / 360
# Computing SVM classification for input stimuli: srRed for ROI 187 / 360
# Computing SVM classification for input stimuli: srRed for ROI 188 / 360
# Computing SVM classification for input stimuli: srRed for ROI 189 / 360
# Computing SVM classification for input stimuli: srRed for ROI 190 / 360
# Computing SVM classification for input stimuli: srRed for ROI 191 / 360
# Computing SVM classification for input stimuli: srRed for ROI 192 / 360
# Computing SVM classification for input stimuli: srRed for ROI 193 / 360
# Computing SVM classification for input stimuli: srRed for ROI 194 / 360
# Computing SVM classification for input stimuli: srRed for ROI 195 / 360
# Computing SVM classification for input stimuli: srRed for ROI 196 / 360
# Computing SVM classification for input stimuli: srRed for ROI 197 / 360
# Computing SVM classification for input stimuli: srRed for ROI 198 / 360
# Computing SVM classification for input stimuli: srRed for ROI 199 / 360
# Computing SVM classification for input stimuli: srRed for ROI 200 / 360
# Computing SVM classification for input stimuli: srRed for ROI 201 / 360
# Computing SVM classification for input stimuli: srRed for ROI 202 / 360
# Computing SVM classification for input stimuli: srRed for ROI 203 / 360
# Computing SVM classification for input stimuli: srRed for ROI 204 / 360
# Computing SVM classification for input stimuli: srRed for ROI 205 / 360
# Computing SVM classification for input stimuli: srRed for ROI 206 / 360
# Computing SVM classification for input stimuli: srRed for ROI 207 / 360
# Computing SVM classification for input stimuli: srRed for ROI 208 / 360
# Computing SVM classification for input stimuli: srRed for ROI 209 / 360
# Computing SVM classification for input stimuli: srRed for ROI 210 / 360
# Computing SVM classification for input stimuli: srRed for ROI 211 / 360
# Computing SVM classification for input stimuli: srRed for ROI 212 / 360
# Computing SVM classification for input stimuli: srRed for ROI 213 / 360
# Computing SVM classification for input stimuli: srRed for ROI 214 / 360
# Computing SVM classification for input stimuli: srRed for ROI 215 / 360
# Computing SVM classification for input stimuli: srRed for ROI 216 / 360
# Computing SVM classification for input stimuli: srRed for ROI 217 / 360
# Computing SVM classification for input stimuli: srRed for ROI 218 / 360
# Computing SVM classification for input stimuli: srRed for ROI 219 / 360
# Computing SVM classification for input stimuli: srRed for ROI 220 / 360
# Computing SVM classification for input stimuli: srRed for ROI 221 / 360
# Computing SVM classification for input stimuli: srRed for ROI 222 / 360
# Computing SVM classification for input stimuli: srRed for ROI 223 / 360
# Computing SVM classification for input stimuli: srRed for ROI 224 / 360
# Computing SVM classification for input stimuli: srRed for ROI 225 / 360
# Computing SVM classification for input stimuli: srRed for ROI 226 / 360
# Computing SVM classification for input stimuli: srRed for ROI 227 / 360
# Computing SVM classification for input stimuli: srRed for ROI 228 / 360
# Computing SVM classification for input stimuli: srRed for ROI 229 / 360
# Computing SVM classification for input stimuli: srRed for ROI 230 / 360
# Computing SVM classification for input stimuli: srRed for ROI 231 / 360
# Computing SVM classification for input stimuli: srRed for ROI 232 / 360
# Computing SVM classification for input stimuli: srRed for ROI 233 / 360
# Computing SVM classification for input stimuli: srRed for ROI 234 / 360
# Computing SVM classification for input stimuli: srRed for ROI 235 / 360
# Computing SVM classification for input stimuli: srRed for ROI 236 / 360
# Computing SVM classification for input stimuli: srRed for ROI 237 / 360
# Computing SVM classification for input stimuli: srRed for ROI 238 / 360
# Computing SVM classification for input stimuli: srRed for ROI 239 / 360
# Computing SVM classification for input stimuli: srRed for ROI 240 / 360
# Computing SVM classification for input stimuli: srRed for ROI 241 / 360
# Computing SVM classification for input stimuli: srRed for ROI 242 / 360
# Computing SVM classification for input stimuli: srRed for ROI 243 / 360
# Computing SVM classification for input stimuli: srRed for ROI 244 / 360
# Computing SVM classification for input stimuli: srRed for ROI 245 / 360
# Computing SVM classification for input stimuli: srRed for ROI 246 / 360
# Computing SVM classification for input stimuli: srRed for ROI 247 / 360
# Computing SVM classification for input stimuli: srRed for ROI 248 / 360
# Computing SVM classification for input stimuli: srRed for ROI 249 / 360
# Computing SVM classification for input stimuli: srRed for ROI 250 / 360
# Computing SVM classification for input stimuli: srRed for ROI 251 / 360
# Computing SVM classification for input stimuli: srRed for ROI 252 / 360
# Computing SVM classification for input stimuli: srRed for ROI 253 / 360
# Computing SVM classification for input stimuli: srRed for ROI 254 / 360
# Computing SVM classification for input stimuli: srRed for ROI 255 / 360
# Computing SVM classification for input stimuli: srRed for ROI 256 / 360
# Computing SVM classification for input stimuli: srRed for ROI 257 / 360
# Computing SVM classification for input stimuli: srRed for ROI 258 / 360
# Computing SVM classification for input stimuli: srRed for ROI 259 / 360
# Computing SVM classification for input stimuli: srRed for ROI 260 / 360
# Computing SVM classification for input stimuli: srRed for ROI 261 / 360
# Computing SVM classification for input stimuli: srRed for ROI 262 / 360
# Computing SVM classification for input stimuli: srRed for ROI 263 / 360
# Computing SVM classification for input stimuli: srRed for ROI 264 / 360
# Computing SVM classification for input stimuli: srRed for ROI 265 / 360
# Computing SVM classification for input stimuli: srRed for ROI 266 / 360
# Computing SVM classification for input stimuli: srRed for ROI 267 / 360
# Computing SVM classification for input stimuli: srRed for ROI 268 / 360
# Computing SVM classification for input stimuli: srRed for ROI 269 / 360
# Computing SVM classification for input stimuli: srRed for ROI 270 / 360
# Computing SVM classification for input stimuli: srRed for ROI 271 / 360
# Computing SVM classification for input stimuli: srRed for ROI 272 / 360
# Computing SVM classification for input stimuli: srRed for ROI 273 / 360
# Computing SVM classification for input stimuli: srRed for ROI 274 / 360
# Computing SVM classification for input stimuli: srRed for ROI 275 / 360
# Computing SVM classification for input stimuli: srRed for ROI 276 / 360
# Computing SVM classification for input stimuli: srRed for ROI 277 / 360
# Computing SVM classification for input stimuli: srRed for ROI 278 / 360
# Computing SVM classification for input stimuli: srRed for ROI 279 / 360
# Computing SVM classification for input stimuli: srRed for ROI 280 / 360
# Computing SVM classification for input stimuli: srRed for ROI 281 / 360
# Computing SVM classification for input stimuli: srRed for ROI 282 / 360
# Computing SVM classification for input stimuli: srRed for ROI 283 / 360
# Computing SVM classification for input stimuli: srRed for ROI 284 / 360
# Computing SVM classification for input stimuli: srRed for ROI 285 / 360
# Computing SVM classification for input stimuli: srRed for ROI 286 / 360
# Computing SVM classification for input stimuli: srRed for ROI 287 / 360
# Computing SVM classification for input stimuli: srRed for ROI 288 / 360
# Computing SVM classification for input stimuli: srRed for ROI 289 / 360
# Computing SVM classification for input stimuli: srRed for ROI 290 / 360
# Computing SVM classification for input stimuli: srRed for ROI 291 / 360
# Computing SVM classification for input stimuli: srRed for ROI 292 / 360
# Computing SVM classification for input stimuli: srRed for ROI 293 / 360
# Computing SVM classification for input stimuli: srRed for ROI 294 / 360
# Computing SVM classification for input stimuli: srRed for ROI 295 / 360
# Computing SVM classification for input stimuli: srRed for ROI 296 / 360
# Computing SVM classification for input stimuli: srRed for ROI 297 / 360
# Computing SVM classification for input stimuli: srRed for ROI 298 / 360
# Computing SVM classification for input stimuli: srRed for ROI 299 / 360
# Computing SVM classification for input stimuli: srRed for ROI 300 / 360
# Computing SVM classification for input stimuli: srRed for ROI 301 / 360
# Computing SVM classification for input stimuli: srRed for ROI 302 / 360
# Computing SVM classification for input stimuli: srRed for ROI 303 / 360
# Computing SVM classification for input stimuli: srRed for ROI 304 / 360
# Computing SVM classification for input stimuli: srRed for ROI 305 / 360
# Computing SVM classification for input stimuli: srRed for ROI 306 / 360
# Computing SVM classification for input stimuli: srRed for ROI 307 / 360
# Computing SVM classification for input stimuli: srRed for ROI 308 / 360
# Computing SVM classification for input stimuli: srRed for ROI 309 / 360
# Computing SVM classification for input stimuli: srRed for ROI 310 / 360
# Computing SVM classification for input stimuli: srRed for ROI 311 / 360
# Computing SVM classification for input stimuli: srRed for ROI 312 / 360
# Computing SVM classification for input stimuli: srRed for ROI 313 / 360
# Computing SVM classification for input stimuli: srRed for ROI 314 / 360
# Computing SVM classification for input stimuli: srRed for ROI 315 / 360
# Computing SVM classification for input stimuli: srRed for ROI 316 / 360
# Computing SVM classification for input stimuli: srRed for ROI 317 / 360
# Computing SVM classification for input stimuli: srRed for ROI 318 / 360
# Computing SVM classification for input stimuli: srRed for ROI 319 / 360
# Computing SVM classification for input stimuli: srRed for ROI 320 / 360
# Computing SVM classification for input stimuli: srRed for ROI 321 / 360
# Computing SVM classification for input stimuli: srRed for ROI 322 / 360
# Computing SVM classification for input stimuli: srRed for ROI 323 / 360
# Computing SVM classification for input stimuli: srRed for ROI 324 / 360
# Computing SVM classification for input stimuli: srRed for ROI 325 / 360
# Computing SVM classification for input stimuli: srRed for ROI 326 / 360
# Computing SVM classification for input stimuli: srRed for ROI 327 / 360
# Computing SVM classification for input stimuli: srRed for ROI 328 / 360
# Computing SVM classification for input stimuli: srRed for ROI 329 / 360
# Computing SVM classification for input stimuli: srRed for ROI 330 / 360
# Computing SVM classification for input stimuli: srRed for ROI 331 / 360
# Computing SVM classification for input stimuli: srRed for ROI 332 / 360
# Computing SVM classification for input stimuli: srRed for ROI 333 / 360
# Computing SVM classification for input stimuli: srRed for ROI 334 / 360
# Computing SVM classification for input stimuli: srRed for ROI 335 / 360
# Computing SVM classification for input stimuli: srRed for ROI 336 / 360
# Computing SVM classification for input stimuli: srRed for ROI 337 / 360
# Computing SVM classification for input stimuli: srRed for ROI 338 / 360
# Computing SVM classification for input stimuli: srRed for ROI 339 / 360
# Computing SVM classification for input stimuli: srRed for ROI 340 / 360
# Computing SVM classification for input stimuli: srRed for ROI 341 / 360
# Computing SVM classification for input stimuli: srRed for ROI 342 / 360
# Computing SVM classification for input stimuli: srRed for ROI 343 / 360
# Computing SVM classification for input stimuli: srRed for ROI 344 / 360
# Computing SVM classification for input stimuli: srRed for ROI 345 / 360
# Computing SVM classification for input stimuli: srRed for ROI 346 / 360
# Computing SVM classification for input stimuli: srRed for ROI 347 / 360
# Computing SVM classification for input stimuli: srRed for ROI 348 / 360
# Computing SVM classification for input stimuli: srRed for ROI 349 / 360
# Computing SVM classification for input stimuli: srRed for ROI 350 / 360
# Computing SVM classification for input stimuli: srRed for ROI 351 / 360
# Computing SVM classification for input stimuli: srRed for ROI 352 / 360
# Computing SVM classification for input stimuli: srRed for ROI 353 / 360
# Computing SVM classification for input stimuli: srRed for ROI 354 / 360
# Computing SVM classification for input stimuli: srRed for ROI 355 / 360
# Computing SVM classification for input stimuli: srRed for ROI 356 / 360
# Computing SVM classification for input stimuli: srRed for ROI 357 / 360
# Computing SVM classification for input stimuli: srRed for ROI 358 / 360
# Computing SVM classification for input stimuli: srRed for ROI 359 / 360

# %% [markdown]
# ## 1.2 Compute statistics

# %%
# if inputtype in ['cproColorStim','cproOriStim']:
#     # Visual networks
#     rois = np.where((networkdef==networkmappings['vis1']) | (networkdef==networkmappings['vis2']))[0] 
#     rois = rois + 1
# elif inputtype in ['cproConstantStim','cproPitchStim']:
#     rois = np.where(networkdef==networkmappings['aud'])[0]
#     rois = rois + 1

rois = np.arange(nParcels)

nStims = 4
statistics = np.zeros((len(rois),3)) # acc, q, acc_thresh
for roicount in range(len(rois)):
    ntrials = len(subjNums)*nStims
    p = stats.binom_test(np.mean(distances_baseline[roicount,:])*ntrials,n=ntrials,p=1/float(nStims))
    if np.mean(distances_baseline[roicount,:])>1/float(nStims):
        p = p/2.0
    else:
        p = 1.0-p/2.0
        

    statistics[roicount,0] = np.mean(distances_baseline[roicount,:])
    statistics[roicount,1] = p

h0, qs = mc.fdrcorrection0(statistics[:,1])
for roicount in range(len(rois)):
    statistics[roicount,1] = qs[roicount]
    statistics[roicount,2] = h0[roicount]*statistics[roicount,0]

# %%
# Count number of significant ROIs for LH decoding
sig_ind = np.where(statistics[:,1]<0.05)[0]
print 'Number of ROIs significant for', sr_rule, 'Stimuli:', sig_ind.shape[0]
print 'Accuracies:', statistics[sig_ind,0]
# Out:
# Number of ROIs significant for srRed Stimuli: 14
# Accuracies: [ 0.31770833  0.32291667  0.31510417  0.33072917  0.3203125   0.32552083
#   0.32552083  0.31510417  0.31510417  0.3359375   0.33333333  0.3203125
#   0.328125    0.31510417]

# %% [markdown]
# ## 1.3 Map accuracies back to cortical surface

# %%
# Put all data into a single matrix (since we only run a single classification)
srStats = np.zeros((glasser2.shape[0],3))

roicount = 0
for roi in rois:
    vertex_ind = np.where(glasser2==roi)[0]
    srStats[vertex_ind,0] = statistics[roicount,0]
    srStats[vertex_ind,1] = statistics[roicount,1]
    srStats[vertex_ind,2] = statistics[roicount,2]

    roicount += 1

    
#### 
# Write file to csv and run wb_command
outdir = '/projects3/SRActFlow/data/results/Decoding_SR/'
filename = sr_rule + '_SR_Decoding'
np.savetxt(outdir + filename + '.csv', srStats,fmt='%s')
wb_file = filename + '.dscalar.nii'
wb_command = 'wb_command -cifti-convert -from-text ' + outdir + filename + '.csv ' + glasserfile2 + ' ' + outdir + wb_file + ' -reset-scalars'
os.system(wb_command)
# Out:
# 0

# %% [markdown]
# # 2.0 Run across subject decoding on VERTICAL SR rules
# ### 4-way decoding
# * both vertical
# * notboth vertical
# * either vertical
# * neither vertical

# %% [markdown]
# ## 1.1 Load data for VERTICAL SR integration

# %%
# gsr = True
nStims = 4
data_task = np.zeros((len(glasser2),nStims,len(subjNums)))
sr_rule = 'srVertical'

scount = 0
for subj in subjNums:
    data_task[:,:,scount] = loadInputActivity(subj,sr_rule)
    scount += 1

# %%
nproc = 30
ncvs = 1

distances_baseline = srDecoding(data_task, sr_rule, ncvs=ncvs, nproc=nproc)
# Out:
# Computing SVM classification for input stimuli: srVertical for ROI 0 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 1 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 2 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 3 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 4 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 5 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 6 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 7 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 8 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 9 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 10 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 11 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 12 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 13 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 14 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 15 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 16 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 17 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 18 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 19 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 20 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 21 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 22 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 23 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 24 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 25 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 26 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 27 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 28 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 29 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 30 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 31 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 32 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 33 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 34 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 35 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 36 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 37 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 38 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 39 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 40 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 41 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 42 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 43 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 44 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 45 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 46 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 47 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 48 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 49 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 50 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 51 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 52 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 53 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 54 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 55 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 56 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 57 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 58 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 59 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 60 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 61 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 62 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 63 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 64 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 65 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 66 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 67 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 68 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 69 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 70 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 71 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 72 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 73 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 74 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 75 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 76 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 77 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 78 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 79 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 80 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 81 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 82 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 83 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 84 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 85 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 86 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 87 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 88 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 89 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 90 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 91 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 92 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 93 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 94 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 95 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 96 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 97 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 98 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 99 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 100 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 101 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 102 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 103 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 104 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 105 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 106 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 107 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 108 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 109 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 110 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 111 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 112 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 113 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 114 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 115 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 116 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 117 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 118 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 119 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 120 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 121 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 122 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 123 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 124 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 125 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 126 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 127 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 128 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 129 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 130 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 131 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 132 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 133 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 134 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 135 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 136 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 137 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 138 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 139 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 140 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 141 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 142 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 143 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 144 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 145 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 146 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 147 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 148 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 149 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 150 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 151 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 152 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 153 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 154 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 155 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 156 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 157 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 158 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 159 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 160 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 161 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 162 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 163 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 164 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 165 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 166 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 167 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 168 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 169 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 170 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 171 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 172 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 173 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 174 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 175 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 176 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 177 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 178 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 179 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 180 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 181 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 182 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 183 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 184 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 185 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 186 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 187 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 188 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 189 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 190 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 191 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 192 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 193 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 194 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 195 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 196 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 197 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 198 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 199 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 200 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 201 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 202 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 203 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 204 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 205 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 206 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 207 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 208 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 209 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 210 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 211 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 212 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 213 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 214 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 215 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 216 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 217 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 218 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 219 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 220 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 221 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 222 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 223 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 224 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 225 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 226 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 227 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 228 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 229 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 230 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 231 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 232 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 233 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 234 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 235 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 236 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 237 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 238 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 239 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 240 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 241 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 242 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 243 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 244 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 245 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 246 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 247 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 248 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 249 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 250 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 251 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 252 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 253 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 254 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 255 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 256 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 257 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 258 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 259 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 260 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 261 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 262 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 263 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 264 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 265 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 266 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 267 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 268 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 269 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 270 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 271 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 272 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 273 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 274 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 275 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 276 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 277 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 278 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 279 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 280 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 281 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 282 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 283 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 284 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 285 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 286 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 287 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 288 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 289 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 290 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 291 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 292 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 293 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 294 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 295 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 296 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 297 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 298 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 299 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 300 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 301 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 302 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 303 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 304 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 305 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 306 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 307 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 308 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 309 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 310 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 311 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 312 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 313 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 314 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 315 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 316 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 317 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 318 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 319 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 320 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 321 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 322 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 323 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 324 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 325 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 326 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 327 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 328 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 329 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 330 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 331 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 332 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 333 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 334 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 335 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 336 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 337 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 338 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 339 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 340 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 341 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 342 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 343 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 344 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 345 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 346 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 347 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 348 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 349 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 350 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 351 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 352 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 353 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 354 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 355 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 356 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 357 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 358 / 360
# Computing SVM classification for input stimuli: srVertical for ROI 359 / 360

# %% [markdown]
# ## 1.2 Compute statistics

# %%
# if inputtype in ['cproColorStim','cproOriStim']:
#     # Visual networks
#     rois = np.where((networkdef==networkmappings['vis1']) | (networkdef==networkmappings['vis2']))[0] 
#     rois = rois + 1
# elif inputtype in ['cproConstantStim','cproPitchStim']:
#     rois = np.where(networkdef==networkmappings['aud'])[0]
#     rois = rois + 1

rois = np.arange(nParcels)

nStims = 4
statistics = np.zeros((len(rois),3)) # acc, q, acc_thresh
for roicount in range(len(rois)):
    ntrials = len(subjNums)*nStims
    p = stats.binom_test(np.mean(distances_baseline[roicount,:])*ntrials,n=ntrials,p=1/float(nStims))
    if np.mean(distances_baseline[roicount,:])>1/float(nStims):
        p = p/2.0
    else:
        p = 1.0-p/2.0
        

    statistics[roicount,0] = np.mean(distances_baseline[roicount,:])
    statistics[roicount,1] = p

h0, qs = mc.fdrcorrection0(statistics[:,1])
for roicount in range(len(rois)):
    statistics[roicount,1] = qs[roicount]
    statistics[roicount,2] = h0[roicount]*statistics[roicount,0]

# %%
# Count number of significant ROIs for LH decoding
sig_ind = np.where(statistics[:,1]<0.05)[0]
print 'Number of ROIs significant for', sr_rule, 'Stimuli:', sig_ind.shape[0]
print 'Accuracies:', statistics[sig_ind,0]
# Out:
# Number of ROIs significant for srVertical Stimuli: 5
# Accuracies: [ 0.32552083  0.3359375   0.33333333  0.33333333  0.328125  ]

# %% [markdown]
# ## 1.3 Map accuracies back to cortical surface

# %%
# Put all data into a single matrix (since we only run a single classification)
srStats = np.zeros((glasser2.shape[0],3))

roicount = 0
for roi in rois:
    vertex_ind = np.where(glasser2==roi)[0]
    srStats[vertex_ind,0] = statistics[roicount,0]
    srStats[vertex_ind,1] = statistics[roicount,1]
    srStats[vertex_ind,2] = statistics[roicount,2]

    roicount += 1

    
#### 
# Write file to csv and run wb_command
outdir = '/projects3/SRActFlow/data/results/Decoding_SR/'
filename = sr_rule + '_SR_Decoding'
np.savetxt(outdir + filename + '.csv', srStats,fmt='%s')
wb_file = filename + '.dscalar.nii'
wb_command = 'wb_command -cifti-convert -from-text ' + outdir + filename + '.csv ' + glasserfile2 + ' ' + outdir + wb_file + ' -reset-scalars'
os.system(wb_command)
# Out:
# 0

# %% [markdown]
# # 3.0 Run across subject decoding on HIGH SR rules
# ### 4-way decoding
# * both high
# * notboth high
# * either high
# * neither high

# %% [markdown]
# ## 1.1 Load data for HIGH SR integration

# %%
# gsr = True
nStims = 4
data_task = np.zeros((len(glasser2),nStims,len(subjNums)))
sr_rule = 'srHigh'

scount = 0
for subj in subjNums:
    data_task[:,:,scount] = loadInputActivity(subj,sr_rule)
    scount += 1

# %%
nproc = 30
ncvs = 1

distances_baseline = srDecoding(data_task, sr_rule, ncvs=ncvs, nproc=nproc)
# Out:
# Computing SVM classification for input stimuli: srHigh for ROI 0 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 1 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 2 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 3 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 4 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 5 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 6 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 7 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 8 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 9 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 10 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 11 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 12 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 13 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 14 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 15 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 16 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 17 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 18 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 19 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 20 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 21 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 22 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 23 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 24 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 25 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 26 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 27 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 28 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 29 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 30 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 31 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 32 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 33 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 34 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 35 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 36 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 37 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 38 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 39 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 40 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 41 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 42 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 43 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 44 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 45 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 46 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 47 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 48 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 49 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 50 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 51 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 52 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 53 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 54 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 55 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 56 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 57 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 58 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 59 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 60 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 61 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 62 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 63 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 64 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 65 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 66 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 67 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 68 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 69 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 70 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 71 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 72 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 73 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 74 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 75 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 76 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 77 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 78 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 79 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 80 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 81 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 82 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 83 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 84 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 85 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 86 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 87 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 88 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 89 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 90 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 91 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 92 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 93 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 94 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 95 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 96 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 97 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 98 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 99 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 100 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 101 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 102 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 103 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 104 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 105 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 106 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 107 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 108 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 109 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 110 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 111 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 112 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 113 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 114 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 115 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 116 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 117 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 118 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 119 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 120 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 121 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 122 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 123 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 124 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 125 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 126 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 127 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 128 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 129 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 130 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 131 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 132 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 133 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 134 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 135 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 136 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 137 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 138 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 139 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 140 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 141 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 142 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 143 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 144 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 145 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 146 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 147 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 148 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 149 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 150 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 151 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 152 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 153 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 154 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 155 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 156 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 157 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 158 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 159 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 160 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 161 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 162 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 163 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 164 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 165 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 166 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 167 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 168 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 169 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 170 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 171 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 172 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 173 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 174 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 175 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 176 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 177 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 178 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 179 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 180 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 181 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 182 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 183 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 184 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 185 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 186 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 187 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 188 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 189 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 190 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 191 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 192 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 193 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 194 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 195 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 196 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 197 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 198 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 199 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 200 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 201 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 202 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 203 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 204 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 205 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 206 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 207 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 208 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 209 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 210 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 211 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 212 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 213 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 214 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 215 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 216 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 217 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 218 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 219 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 220 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 221 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 222 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 223 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 224 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 225 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 226 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 227 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 228 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 229 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 230 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 231 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 232 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 233 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 234 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 235 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 236 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 237 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 238 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 239 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 240 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 241 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 242 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 243 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 244 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 245 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 246 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 247 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 248 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 249 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 250 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 251 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 252 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 253 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 254 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 255 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 256 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 257 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 258 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 259 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 260 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 261 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 262 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 263 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 264 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 265 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 266 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 267 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 268 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 269 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 270 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 271 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 272 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 273 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 274 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 275 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 276 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 277 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 278 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 279 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 280 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 281 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 282 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 283 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 284 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 285 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 286 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 287 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 288 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 289 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 290 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 291 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 292 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 293 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 294 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 295 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 296 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 297 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 298 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 299 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 300 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 301 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 302 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 303 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 304 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 305 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 306 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 307 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 308 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 309 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 310 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 311 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 312 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 313 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 314 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 315 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 316 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 317 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 318 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 319 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 320 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 321 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 322 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 323 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 324 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 325 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 326 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 327 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 328 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 329 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 330 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 331 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 332 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 333 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 334 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 335 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 336 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 337 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 338 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 339 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 340 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 341 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 342 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 343 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 344 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 345 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 346 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 347 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 348 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 349 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 350 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 351 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 352 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 353 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 354 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 355 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 356 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 357 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 358 / 360
# Computing SVM classification for input stimuli: srHigh for ROI 359 / 360

# %% [markdown]
# ## 1.2 Compute statistics

# %%
# if inputtype in ['cproColorStim','cproOriStim']:
#     # Visual networks
#     rois = np.where((networkdef==networkmappings['vis1']) | (networkdef==networkmappings['vis2']))[0] 
#     rois = rois + 1
# elif inputtype in ['cproConstantStim','cproPitchStim']:
#     rois = np.where(networkdef==networkmappings['aud'])[0]
#     rois = rois + 1

rois = np.arange(nParcels)

nStims = 4
statistics = np.zeros((len(rois),3)) # acc, q, acc_thresh
for roicount in range(len(rois)):
    ntrials = len(subjNums)*nStims
    p = stats.binom_test(np.mean(distances_baseline[roicount,:])*ntrials,n=ntrials,p=1/float(nStims))
    if np.mean(distances_baseline[roicount,:])>1/float(nStims):
        p = p/2.0
    else:
        p = 1.0-p/2.0
        

    statistics[roicount,0] = np.mean(distances_baseline[roicount,:])
    statistics[roicount,1] = p

h0, qs = mc.fdrcorrection0(statistics[:,1])
for roicount in range(len(rois)):
    statistics[roicount,1] = qs[roicount]
    statistics[roicount,2] = h0[roicount]*statistics[roicount,0]

# %%
# Count number of significant ROIs for LH decoding
sig_ind = np.where(statistics[:,1]<0.05)[0]
print 'Number of ROIs significant for', sr_rule, 'Stimuli:', sig_ind.shape[0]
print 'Accuracies:', statistics[sig_ind,0]
# Out:
# Number of ROIs significant for srHigh Stimuli: 2
# Accuracies: [ 0.33854167  0.34114583]

# %% [markdown]
# ## 1.3 Map accuracies back to cortical surface

# %%
# Put all data into a single matrix (since we only run a single classification)
srStats = np.zeros((glasser2.shape[0],3))

roicount = 0
for roi in rois:
    vertex_ind = np.where(glasser2==roi)[0]
    srStats[vertex_ind,0] = statistics[roicount,0]
    srStats[vertex_ind,1] = statistics[roicount,1]
    srStats[vertex_ind,2] = statistics[roicount,2]

    roicount += 1

    
#### 
# Write file to csv and run wb_command
outdir = '/projects3/SRActFlow/data/results/Decoding_SR/'
filename = sr_rule + '_SR_Decoding'
np.savetxt(outdir + filename + '.csv', srStats,fmt='%s')
wb_file = filename + '.dscalar.nii'
wb_command = 'wb_command -cifti-convert -from-text ' + outdir + filename + '.csv ' + glasserfile2 + ' ' + outdir + wb_file + ' -reset-scalars'
os.system(wb_command)
# Out:
# 0

# %% [markdown]
# # 4.0 Run across subject decoding on CONSTANT SR rules
# ### 4-way decoding
# * both constant
# * notboth constant
# * either constant
# * neither constant

# %% [markdown]
# ## 1.1 Load data for CONSTANT SR integration

# %%
# gsr = True
nStims = 4
data_task = np.zeros((len(glasser2),nStims,len(subjNums)))
sr_rule = 'srConstant'

scount = 0
for subj in subjNums:
    data_task[:,:,scount] = loadInputActivity(subj,sr_rule)
    scount += 1

# %%
nproc = 30
ncvs = 1

distances_baseline = srDecoding(data_task, sr_rule, ncvs=ncvs, nproc=nproc)
# Out:
# Computing SVM classification for input stimuli: srConstant for ROI 0 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 1 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 2 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 3 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 4 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 5 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 6 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 7 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 8 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 9 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 10 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 11 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 12 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 13 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 14 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 15 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 16 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 17 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 18 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 19 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 20 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 21 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 22 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 23 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 24 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 25 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 26 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 27 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 28 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 29 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 30 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 31 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 32 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 33 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 34 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 35 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 36 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 37 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 38 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 39 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 40 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 41 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 42 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 43 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 44 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 45 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 46 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 47 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 48 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 49 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 50 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 51 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 52 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 53 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 54 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 55 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 56 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 57 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 58 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 59 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 60 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 61 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 62 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 63 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 64 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 65 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 66 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 67 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 68 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 69 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 70 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 71 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 72 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 73 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 74 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 75 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 76 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 77 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 78 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 79 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 80 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 81 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 82 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 83 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 84 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 85 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 86 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 87 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 88 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 89 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 90 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 91 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 92 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 93 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 94 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 95 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 96 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 97 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 98 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 99 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 100 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 101 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 102 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 103 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 104 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 105 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 106 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 107 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 108 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 109 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 110 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 111 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 112 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 113 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 114 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 115 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 116 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 117 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 118 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 119 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 120 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 121 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 122 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 123 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 124 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 125 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 126 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 127 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 128 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 129 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 130 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 131 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 132 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 133 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 134 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 135 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 136 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 137 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 138 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 139 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 140 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 141 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 142 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 143 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 144 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 145 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 146 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 147 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 148 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 149 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 150 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 151 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 152 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 153 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 154 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 155 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 156 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 157 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 158 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 159 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 160 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 161 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 162 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 163 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 164 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 165 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 166 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 167 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 168 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 169 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 170 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 171 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 172 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 173 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 174 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 175 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 176 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 177 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 178 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 179 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 180 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 181 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 182 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 183 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 184 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 185 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 186 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 187 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 188 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 189 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 190 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 191 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 192 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 193 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 194 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 195 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 196 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 197 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 198 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 199 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 200 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 201 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 202 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 203 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 204 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 205 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 206 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 207 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 208 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 209 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 210 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 211 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 212 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 213 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 214 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 215 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 216 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 217 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 218 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 219 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 220 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 221 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 222 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 223 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 224 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 225 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 226 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 227 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 228 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 229 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 230 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 231 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 232 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 233 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 234 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 235 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 236 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 237 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 238 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 239 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 240 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 241 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 242 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 243 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 244 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 245 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 246 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 247 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 248 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 249 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 250 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 251 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 252 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 253 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 254 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 255 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 256 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 257 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 258 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 259 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 260 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 261 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 262 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 263 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 264 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 265 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 266 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 267 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 268 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 269 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 270 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 271 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 272 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 273 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 274 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 275 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 276 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 277 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 278 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 279 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 280 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 281 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 282 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 283 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 284 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 285 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 286 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 287 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 288 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 289 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 290 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 291 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 292 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 293 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 294 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 295 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 296 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 297 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 298 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 299 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 300 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 301 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 302 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 303 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 304 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 305 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 306 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 307 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 308 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 309 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 310 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 311 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 312 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 313 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 314 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 315 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 316 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 317 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 318 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 319 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 320 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 321 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 322 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 323 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 324 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 325 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 326 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 327 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 328 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 329 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 330 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 331 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 332 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 333 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 334 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 335 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 336 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 337 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 338 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 339 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 340 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 341 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 342 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 343 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 344 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 345 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 346 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 347 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 348 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 349 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 350 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 351 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 352 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 353 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 354 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 355 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 356 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 357 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 358 / 360
# Computing SVM classification for input stimuli: srConstant for ROI 359 / 360

# %% [markdown]
# ## 1.2 Compute statistics

# %%
# if inputtype in ['cproColorStim','cproOriStim']:
#     # Visual networks
#     rois = np.where((networkdef==networkmappings['vis1']) | (networkdef==networkmappings['vis2']))[0] 
#     rois = rois + 1
# elif inputtype in ['cproConstantStim','cproPitchStim']:
#     rois = np.where(networkdef==networkmappings['aud'])[0]
#     rois = rois + 1

rois = np.arange(nParcels)

nStims = 4
statistics = np.zeros((len(rois),3)) # acc, q, acc_thresh
for roicount in range(len(rois)):
    ntrials = len(subjNums)*nStims
    p = stats.binom_test(np.mean(distances_baseline[roicount,:])*ntrials,n=ntrials,p=1/float(nStims))
    if np.mean(distances_baseline[roicount,:])>1/float(nStims):
        p = p/2.0
    else:
        p = 1.0-p/2.0
        

    statistics[roicount,0] = np.mean(distances_baseline[roicount,:])
    statistics[roicount,1] = p

h0, qs = mc.fdrcorrection0(statistics[:,1])
for roicount in range(len(rois)):
    statistics[roicount,1] = qs[roicount]
    statistics[roicount,2] = h0[roicount]*statistics[roicount,0]

# %%
# Count number of significant ROIs for LH decoding
sig_ind = np.where(statistics[:,1]<0.05)[0]
print 'Number of ROIs significant for', sr_rule, 'Stimuli:', sig_ind.shape[0]
print 'Accuracies:', statistics[sig_ind,0]
# Out:
# Number of ROIs significant for srConstant Stimuli: 3
# Accuracies: [ 0.328125   0.3359375  0.328125 ]

# %% [markdown]
# ## 1.3 Map accuracies back to cortical surface

# %%
# Put all data into a single matrix (since we only run a single classification)
srStats = np.zeros((glasser2.shape[0],3))

roicount = 0
for roi in rois:
    vertex_ind = np.where(glasser2==roi)[0]
    srStats[vertex_ind,0] = statistics[roicount,0]
    srStats[vertex_ind,1] = statistics[roicount,1]
    srStats[vertex_ind,2] = statistics[roicount,2]

    roicount += 1

    
#### 
# Write file to csv and run wb_command
outdir = '/projects3/SRActFlow/data/results/Decoding_SR/'
filename = sr_rule + '_SR_Decoding'
np.savetxt(outdir + filename + '.csv', srStats,fmt='%s')
wb_file = filename + '.dscalar.nii'
wb_command = 'wb_command -cifti-convert -from-text ' + outdir + filename + '.csv ' + glasserfile2 + ' ' + outdir + wb_file + ' -reset-scalars'
os.system(wb_command)
# Out:
# 0
