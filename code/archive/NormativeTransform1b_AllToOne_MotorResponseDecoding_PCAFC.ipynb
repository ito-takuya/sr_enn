# %% [markdown]
# # ActFlow 1 -- Compute the baseline decodability of Motor responses (LINDEX v. LMID and RINDEX v. RMID)
# ## Using ActFlow, all to one, via ridge FC
#
# ## Use SVM classifications to decode hand-specific responses
# ## Using Ciric-style postprocessing
#
# ## Takuya Ito
# #### 12/12/2018

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import multiprocessing as mp
import scipy.stats as stats
import nibabel as nib
import os
os.environ['OMP_NUM_THREADS'] = str(1)
import statsmodels.api as sm
import sklearn.svm as svm
import statsmodels.sandbox.stats.multicomp as mc
import sklearn
from sklearn.feature_selection import f_classif
import seaborn as sns
import h5py
os.sys.path.append('glmScripts/')
import taskGLMPipeline as tgp
import statsmodels.api as sm
from sklearn.linear_model import Ridge
from sklearn.decomposition import PCA



sns.set_style("whitegrid")
plt.rcParams["font.family"] = "FreeSans"

# %%
# Excluding 084
subjNums = ['013','014','016','017','018','021','023','024','026','027','028','030','031','032','033',
            '034','035','037','038','039','040','041','042','043','045','046','047','048','049','050',
            '053','055','056','057','058','062','063','066','067','068','069','070','072','074','075',
            '076','077','081','085','086','087','088','090','092','093','094','095','097','098','099',
            '101','102','103','104','105','106','108','109','110','111','112','114','115','117','119',
            '120','121','122','123','124','125','126','127','128','129','130','131','132','134','135',
            '136','137','138','139','140','141']



basedir = '/projects3/SRActFlow/'

# Using final partition
networkdef = np.loadtxt('/projects3/NetworkDiversity/data/network_partition.txt')
networkorder = np.asarray(sorted(range(len(networkdef)), key=lambda k: networkdef[k]))
networkorder.shape = (len(networkorder),1)
# network mappings for final partition set
networkmappings = {'fpn':7, 'vis1':1, 'vis2':2, 'smn':3, 'aud':8, 'lan':6, 'dan':5, 'con':4, 'dmn':9, 
                   'pmulti':10, 'none1':11, 'none2':12}
networks = networkmappings.keys()

xticks = {}
reorderednetworkaffil = networkdef[networkorder]
for net in networks:
    netNum = networkmappings[net]
    netind = np.where(reorderednetworkaffil==netNum)[0]
    tick = np.max(netind)
    xticks[tick] = net

## General parameters/variables
nParcels = 360
nSubjs = len(subjNums)

glasserfile2 = '/projects/AnalysisTools/ParcelsGlasser2016/Q1-Q6_RelatedParcellation210.LR.CorticalAreas_dil_Colors.32k_fs_RL.dlabel.nii'
glasser2 = nib.load(glasserfile2).get_data()
glasser2 = np.squeeze(glasser2)

sortednets = np.sort(xticks.keys())
orderednetworks = []
for net in sortednets: orderednetworks.append(xticks[net])
    
networkpalette = ['royalblue','slateblue','paleturquoise','darkorchid','limegreen',
                  'lightseagreen','yellow','orchid','r','peru','orange','olivedrab']
networkpalette = np.asarray(networkpalette)

OrderedNetworks = ['VIS1','VIS2','SMN','CON','DAN','LAN','FPN','AUD','DMN','PMM','VMM','ORA']

# %% [markdown]
# # 0.0 Define functions for loading data

# %%
def loadMotorResponses(subj,hand='Right'):
    
    hands = {'Left':[0,1],'Right':[2,3]}

    x = tgp.loadTaskTiming(subj,'ALL')
    stimIndex = np.asarray(x['stimIndex'])
    ind = np.where(stimIndex=='motorResponse')[0]
    
    datadir = basedir + 'data/postProcessing/hcpPostProcCiric/'
    h5f = h5py.File(datadir + subj + '_glmOutput_data.h5','r')
    data = h5f['taskRegression/ALL_24pXaCompCorXVolterra_taskReg_betas_canonical'][:].copy()
    data = data[:,ind].copy()
    h5f.close()
    
    # Isolate hand responses
    hand_ind = hands[hand]
    data = data[:,hand_ind]
    
    return data

def loadAllData(subj):
    
    datadir = basedir + 'data/postProcessing/hcpPostProcCiric/'
    h5f = h5py.File(datadir + subj + '_glmOutput_data.h5','r')
    data = h5f['taskRegression/ALL_24pXaCompCorXVolterra_taskReg_betas_canonical'][:].copy()
    h5f.close()    
    return data


def loadRSFCMapping(subj,roi):
    fcdir = '/projects3/SRActFlow/data/results/ridgeFC/'
    filename = fcdir + 'TargetParcel' + str(roi) + '_RidgeFC.h5'
    h5f = h5py.File(filename,'r')
    fcmapping = h5f[subj]['sourceToTargetMapping'][:].copy()
    h5f.close()
    return fcmapping

def ridgeWrapper((stim,resp,alpha)):
#     wt = ridge.ridge.ridge(stim,resp,alpha)
    clf = Ridge(alpha=alpha)
    clf.fit(stim,resp)
    wt = clf.coef_

    return wt

def pcaFC(stim,resp,n_components=500,nproc=10):
#     print '\tRunning PCA'
    os.environ['OMP_NUM_THREADS'] = str(nproc)
    if n_components<stim.shape[1]:
        pca = PCA(n_components)
        reduced_mat = pca.fit_transform(stim) # Time X Features
    else:
        reduced_mat = stim
    
    inputs = []
    for vert in range(resp.shape[1]):
        inputs.append((resp[:,vert],reduced_mat,True))

#     print '\tRunning regression'
    os.environ['OMP_NUM_THREADS'] = str(1)
    pool = mp.Pool(processes=nproc)
    results = pool.map_async(_regression2,inputs).get()
    pool.close()
    pool.join()
    
    
    wt = np.zeros((stim.shape[1],resp.shape[1]))
    vert = 0
    for result in results:
        betas, resid = result
        if n_components<stim.shape[1]:
            betas = pca.inverse_transform(betas[1:])
        else:
            betas = betas[1:]
        wt[:,vert] = betas
        vert += 1

    return wt

def _regression2((data,regressors,constant)):
    """ 
    Hand coded OLS regression using closed form equation: betas = (X'X)^(-1) X'y
    """
    # Add 'constant' regressor
    if constant:
        regressors = sm.add_constant(regressors)
    X = regressors.copy()
    try:
#        #C_ss_inv = np.linalg.inv(np.dot(X.T,X))
        C_ss_inv = np.linalg.pinv(np.dot(X.T,X))
    except np.linalg.LinAlgError as err:
        C_ss_inv = np.linalg.pinv(np.cov(X.T))
    betas = np.dot(C_ss_inv,np.dot(X.T,data.T))
    resid = data - (betas[0] + np.dot(X[:,1:],betas[1:])).T
    return betas, resid

# %% [markdown]
# ## 0.1 Load data

# %%
# gsr = True
nResponses = 2
data_task_rh = np.zeros((len(glasser2),nResponses,len(subjNums)))
data_task_lh = np.zeros((len(glasser2),nResponses,len(subjNums)))

scount = 0
for subj in subjNums:
    data_task_rh[:,:,scount] = loadMotorResponses(subj, hand='Right')
    data_task_lh[:,:,scount] = loadMotorResponses(subj, hand='Left')
    scount += 1

# %%
all_data = np.zeros((len(glasser2),48,len(subjNums)))

scount = 0
for subj in subjNums:
    all_data[:,:,scount] = loadAllData(subj)
    scount += 1

# %% [markdown]
# ## 0.2 Generate normative transformation

# %%
## Load masks
def loadMask(roi,dilated=True):
    maskdir = basedir + 'data/results/surfaceMasks/'
    if dilated:
        maskfile = maskdir + 'GlasserParcel' + str(roi) + '_dilated_10mm.dscalar.nii'
    else:
        maskfile = maskdir + 'GlasserParcel' + str(roi) + '.dscalar.nii'
    maskdata = np.squeeze(nib.load(maskfile).get_data())
    return maskdata

# %%
os.environ['OMP_NUM_THREADS'] = str(20)

roi_rh = 9 # Right finger mappings - left m1/s1
roi_lh = 189 # Left finger mappings -right m1/s1
actflow_data_rh = np.zeros((len(glasser2),2,len(subjNums),nParcels))
actflow_data_lh = np.zeros((len(glasser2),2,len(subjNums),nParcels))

dilateLH = loadMask(roi_lh,dilated=True)
dilateRH = loadMask(roi_rh,dilated=True)
combinedDilated = dilateLH + dilateRH
source_space = np.where(combinedDilated==0)[0]
smn_rois = np.where(networkdef==networkmappings['smn'])[0]

h5f_rh = h5py.File('/projects3/SRActFlow/data/results/normativeFC_pca/TargetParcel' + str(roi_rh) + '_NormativeFC.h5','a')
h5f_lh = h5py.File('/projects3/SRActFlow/data/results/normativeFC_pca/TargetParcel' + str(roi_lh) + '_NormativeFC.h5','a')

scount = 0
for subj in subjNums:
    print 'Subject', subj, '(', scount+1, '/', len(subjNums), ')'
    training_subjs = np.delete(np.arange(len(subjNums)),scount)
        
    for roi in range(nParcels):
#         if roi%30==0: print '\tROI number', roi+1
        print '\tROI number', roi+1
        source_ind = np.where(glasser2==roi+1)[0]
        source_ind = np.intersect1d(source_ind,source_space) # Make sure no vertices are within 10mm of the target
        if roi in smn_rois: 
            continue
        if source_ind.shape[0]==0:
            continue

        #### Right finger mappings
        target_ind = np.where(glasser2==roi_rh)[0]
        targetTrain = all_data[:,:,training_subjs].T.reshape(len(training_subjs)*all_data.shape[1],len(glasser2))[:,target_ind]
        sourceTrain = all_data[:,:,training_subjs].T.reshape(len(training_subjs)*all_data.shape[1],len(glasser2))[:,source_ind]
        normativeMapping = pcaFC(sourceTrain,targetTrain,n_components=500,nproc=20)
        h5f_rh.create_dataset(subj + '/OneToOne_Source' + str(roi+1),data=normativeMapping)
        
        # Right Finger 1
        actflow_data_rh[target_ind,0,scount,roi] = np.dot(stats.zscore(data_task_rh[source_ind,0,scount],axis=0),normativeMapping[:,:])
        # Right Finger 2
        actflow_data_rh[target_ind,1,scount,roi] = np.dot(stats.zscore(data_task_rh[source_ind,1,scount],axis=0),normativeMapping[:,:])

        #### Left finger mappings
        target_ind = np.where(glasser2==roi_lh)[0]
        targetTrain = all_data[:,:,training_subjs].T.reshape(len(training_subjs)*all_data.shape[1],len(glasser2))[:,target_ind]
        sourceTrain = all_data[:,:,training_subjs].T.reshape(len(training_subjs)*all_data.shape[1],len(glasser2))[:,source_ind]
        normativeMapping = pcaFC(sourceTrain,targetTrain,n_components=500,nproc=20)
        h5f_lh.create_dataset(subj + '/OneToOne_Source' + str(roi+1),data=normativeMapping)


        # Left Finger 1
        actflow_data_lh[target_ind,0,scount,roi] = np.dot(stats.zscore(data_task_lh[source_ind,0,scount],axis=0),normativeMapping[:,:])
        # Left Finger 2
        actflow_data_lh[target_ind,1,scount,roi] = np.dot(stats.zscore(data_task_lh[source_ind,1,scount],axis=0),normativeMapping[:,:])
    
    scount += 1

h5f_rh.close()
h5f_lh.close()
# Out:
# Subject 013 ( 1 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 014 ( 2 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 016 ( 3 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 017 ( 4 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 018 ( 5 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 021 ( 6 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 023 ( 7 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 024 ( 8 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 026 ( 9 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# ...
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 123 ( 79 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 124 ( 80 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130
# 	ROI number 131
# 	ROI number 132
# 	ROI number 133
# 	ROI number 134
# 	ROI number 135
# 	ROI number 136
# 	ROI number 137
# 	ROI number 138
# 	ROI number 139
# 	ROI number 140
# 	ROI number 141
# 	ROI number 142
# 	ROI number 143
# 	ROI number 144
# 	ROI number 145
# 	ROI number 146
# 	ROI number 147
# 	ROI number 148
# 	ROI number 149
# 	ROI number 150
# 	ROI number 151
# 	ROI number 152
# 	ROI number 153
# 	ROI number 154
# 	ROI number 155
# 	ROI number 156
# 	ROI number 157
# 	ROI number 158
# 	ROI number 159
# 	ROI number 160
# 	ROI number 161
# 	ROI number 162
# 	ROI number 163
# 	ROI number 164
# 	ROI number 165
# 	ROI number 166
# 	ROI number 167
# 	ROI number 168
# 	ROI number 169
# 	ROI number 170
# 	ROI number 171
# 	ROI number 172
# 	ROI number 173
# 	ROI number 174
# 	ROI number 175
# 	ROI number 176
# 	ROI number 177
# 	ROI number 178
# 	ROI number 179
# 	ROI number 180
# 	ROI number 181
# 	ROI number 182
# 	ROI number 183
# 	ROI number 184
# 	ROI number 185
# 	ROI number 186
# 	ROI number 187
# 	ROI number 188
# 	ROI number 189
# 	ROI number 190
# 	ROI number 191
# 	ROI number 192
# 	ROI number 193
# 	ROI number 194
# 	ROI number 195
# 	ROI number 196
# 	ROI number 197
# 	ROI number 198
# 	ROI number 199
# 	ROI number 200
# 	ROI number 201
# 	ROI number 202
# 	ROI number 203
# 	ROI number 204
# 	ROI number 205
# 	ROI number 206
# 	ROI number 207
# 	ROI number 208
# 	ROI number 209
# 	ROI number 210
# 	ROI number 211
# 	ROI number 212
# 	ROI number 213
# 	ROI number 214
# 	ROI number 215
# 	ROI number 216
# 	ROI number 217
# 	ROI number 218
# 	ROI number 219
# 	ROI number 220
# 	ROI number 221
# 	ROI number 222
# 	ROI number 223
# 	ROI number 224
# 	ROI number 225
# 	ROI number 226
# 	ROI number 227
# 	ROI number 228
# 	ROI number 229
# 	ROI number 230
# 	ROI number 231
# 	ROI number 232
# 	ROI number 233
# 	ROI number 234
# 	ROI number 235
# 	ROI number 236
# 	ROI number 237
# 	ROI number 238
# 	ROI number 239
# 	ROI number 240
# 	ROI number 241
# 	ROI number 242
# 	ROI number 243
# 	ROI number 244
# 	ROI number 245
# 	ROI number 246
# 	ROI number 247
# 	ROI number 248
# 	ROI number 249
# 	ROI number 250
# 	ROI number 251
# 	ROI number 252
# 	ROI number 253
# 	ROI number 254
# 	ROI number 255
# 	ROI number 256
# 	ROI number 257
# 	ROI number 258
# 	ROI number 259
# 	ROI number 260
# 	ROI number 261
# 	ROI number 262
# 	ROI number 263
# 	ROI number 264
# 	ROI number 265
# 	ROI number 266
# 	ROI number 267
# 	ROI number 268
# 	ROI number 269
# 	ROI number 270
# 	ROI number 271
# 	ROI number 272
# 	ROI number 273
# 	ROI number 274
# 	ROI number 275
# 	ROI number 276
# 	ROI number 277
# 	ROI number 278
# 	ROI number 279
# 	ROI number 280
# 	ROI number 281
# 	ROI number 282
# 	ROI number 283
# 	ROI number 284
# 	ROI number 285
# 	ROI number 286
# 	ROI number 287
# 	ROI number 288
# 	ROI number 289
# 	ROI number 290
# 	ROI number 291
# 	ROI number 292
# 	ROI number 293
# 	ROI number 294
# 	ROI number 295
# 	ROI number 296
# 	ROI number 297
# 	ROI number 298
# 	ROI number 299
# 	ROI number 300
# 	ROI number 301
# 	ROI number 302
# 	ROI number 303
# 	ROI number 304
# 	ROI number 305
# 	ROI number 306
# 	ROI number 307
# 	ROI number 308
# 	ROI number 309
# 	ROI number 310
# 	ROI number 311
# 	ROI number 312
# 	ROI number 313
# 	ROI number 314
# 	ROI number 315
# 	ROI number 316
# 	ROI number 317
# 	ROI number 318
# 	ROI number 319
# 	ROI number 320
# 	ROI number 321
# 	ROI number 322
# 	ROI number 323
# 	ROI number 324
# 	ROI number 325
# 	ROI number 326
# 	ROI number 327
# 	ROI number 328
# 	ROI number 329
# 	ROI number 330
# 	ROI number 331
# 	ROI number 332
# 	ROI number 333
# 	ROI number 334
# 	ROI number 335
# 	ROI number 336
# 	ROI number 337
# 	ROI number 338
# 	ROI number 339
# 	ROI number 340
# 	ROI number 341
# 	ROI number 342
# 	ROI number 343
# 	ROI number 344
# 	ROI number 345
# 	ROI number 346
# 	ROI number 347
# 	ROI number 348
# 	ROI number 349
# 	ROI number 350
# 	ROI number 351
# 	ROI number 352
# 	ROI number 353
# 	ROI number 354
# 	ROI number 355
# 	ROI number 356
# 	ROI number 357
# 	ROI number 358
# 	ROI number 359
# 	ROI number 360
# Subject 125 ( 81 / 96 )
# 	ROI number 1
# 	ROI number 2
# 	ROI number 3
# 	ROI number 4
# 	ROI number 5
# 	ROI number 6
# 	ROI number 7
# 	ROI number 8
# 	ROI number 9
# 	ROI number 10
# 	ROI number 11
# 	ROI number 12
# 	ROI number 13
# 	ROI number 14
# 	ROI number 15
# 	ROI number 16
# 	ROI number 17
# 	ROI number 18
# 	ROI number 19
# 	ROI number 20
# 	ROI number 21
# 	ROI number 22
# 	ROI number 23
# 	ROI number 24
# 	ROI number 25
# 	ROI number 26
# 	ROI number 27
# 	ROI number 28
# 	ROI number 29
# 	ROI number 30
# 	ROI number 31
# 	ROI number 32
# 	ROI number 33
# 	ROI number 34
# 	ROI number 35
# 	ROI number 36
# 	ROI number 37
# 	ROI number 38
# 	ROI number 39
# 	ROI number 40
# 	ROI number 41
# 	ROI number 42
# 	ROI number 43
# 	ROI number 44
# 	ROI number 45
# 	ROI number 46
# 	ROI number 47
# 	ROI number 48
# 	ROI number 49
# 	ROI number 50
# 	ROI number 51
# 	ROI number 52
# 	ROI number 53
# 	ROI number 54
# 	ROI number 55
# 	ROI number 56
# 	ROI number 57
# 	ROI number 58
# 	ROI number 59
# 	ROI number 60
# 	ROI number 61
# 	ROI number 62
# 	ROI number 63
# 	ROI number 64
# 	ROI number 65
# 	ROI number 66
# 	ROI number 67
# 	ROI number 68
# 	ROI number 69
# 	ROI number 70
# 	ROI number 71
# 	ROI number 72
# 	ROI number 73
# 	ROI number 74
# 	ROI number 75
# 	ROI number 76
# 	ROI number 77
# 	ROI number 78
# 	ROI number 79
# 	ROI number 80
# 	ROI number 81
# 	ROI number 82
# 	ROI number 83
# 	ROI number 84
# 	ROI number 85
# 	ROI number 86
# 	ROI number 87
# 	ROI number 88
# 	ROI number 89
# 	ROI number 90
# 	ROI number 91
# 	ROI number 92
# 	ROI number 93
# 	ROI number 94
# 	ROI number 95
# 	ROI number 96
# 	ROI number 97
# 	ROI number 98
# 	ROI number 99
# 	ROI number 100
# 	ROI number 101
# 	ROI number 102
# 	ROI number 103
# 	ROI number 104
# 	ROI number 105
# 	ROI number 106
# 	ROI number 107
# 	ROI number 108
# 	ROI number 109
# 	ROI number 110
# 	ROI number 111
# 	ROI number 112
# 	ROI number 113
# 	ROI number 114
# 	ROI number 115
# 	ROI number 116
# 	ROI number 117
# 	ROI number 118
# 	ROI number 119
# 	ROI number 120
# 	ROI number 121
# 	ROI number 122
# 	ROI number 123
# 	ROI number 124
# 	ROI number 125
# 	ROI number 126
# 	ROI number 127
# 	ROI number 128
# 	ROI number 129
# 	ROI number 130

# %% [markdown]
# # 1.0 Define functions for motor response decodings

# %%
from scipy.spatial.distance import cdist

def motorResponseDecodings(data, actflow_data, rois=[9], ncvs=1, nproc=5):
    """
    Run an across-subject classification
    Decode responses on each hand separately from CPRO data
    """

    nSubjs = data.shape[2]
    stats = np.zeros((len(rois),nSubjs*2))
    
    nfing = data.shape[1]

    nsamples = nSubjs * nfing

    # Label array for supervised learning
    labels = np.tile(range(nfing),nSubjs)
    subjarray = np.repeat(range(nSubjs),nfing)

    # Run SVM classifications on network-level activation patterns across subjects
    roicount = 0
    for roi in rois:
        roi_ind = np.where(glasser2==roi)[0]
        nfeatures = len(roi_ind)
        roi_ind.shape = (len(roi_ind),1)       

        svm_mat = np.zeros((nsamples,roi_ind.shape[0]))
        actflow_svm_mat = np.zeros((nsamples,roi_ind.shape[0]))
        samplecount = 0
        scount = 0
        for subj in range(len(subjNums)):
            roidata = np.squeeze(data[roi_ind,:,scount])
            actflow_roidata = np.squeeze(actflow_data[roi_ind,:,scount])
            svm_mat[samplecount:(samplecount+nfing),:] = roidata.T
            actflow_svm_mat[samplecount:(samplecount+nfing),:] = actflow_roidata.T

            scount += 1
            samplecount += nfing

#             # Spatially demean matrix across features
#             samplemean = np.mean(svm_mat,axis=1)
#             samplemean.shape = (len(samplemean),1)
#             svm_mat = svm_mat - samplemean

        scores = randomSplitLOOBaselineCV(ncvs, svm_mat, actflow_svm_mat, labels, subjarray, nproc=nproc)
        stats[roicount,:] = scores
        roicount += 1
        
    return stats

def randomSplitLOOBaselineCV(ncvs, svm_mat, actflow_svm_mat, labels, subjarray, nproc=5):
    """
    Runs cross validation for an across-subject SVM analysis
    """
    
    ntasks = len(np.unique(labels))
    nsamples = svm_mat.shape[0]
    nsubjs = nsamples/ntasks

    subjects = np.unique(subjarray)
    indices = np.arange(nsamples)
    
    numsubjs_perfold = 2
    if nsubjs%numsubjs_perfold!=0: 
        raise Exception("Error: Folds don't match number of subjects")
        
    nfolds = nsubjs/numsubjs_perfold
    subj_array_folds = subjarray.copy()
    
    inputs = [] 
    
    for fold in range(nfolds):
        test_subjs = np.random.choice(subj_array_folds,numsubjs_perfold,replace=False)
        train_subjs_all = np.delete(subjects,test_subjs)
        for cv in range(ncvs):
            # Randomly sample half of train set subjects for each cv (CV bootstrapping)
            train_subjs = np.random.choice(train_subjs_all,
                                         int(np.floor(len(train_subjs_all)*(4.0))),
                                         replace=True)

            train_ind = []
            for subj in train_subjs:
                train_ind.extend(np.where(subjarray==subj)[0])

            test_ind = []
            for subj in test_subjs:
                test_ind.extend(np.where(subjarray==subj)[0])
            
            train_ind = np.asarray(train_ind)
            test_ind = np.asarray(test_ind)

            trainset = actflow_svm_mat[train_ind,:]
            testset = svm_mat[test_ind,:]

            # Normalize trainset and testset
            trainmean = np.mean(actflow_svm_mat[train_ind,:],axis=0)
            trainmean.shape = (1,len(trainmean))
            trainstd = np.std(actflow_svm_mat[train_ind,:],axis=0)
            trainstd.shape = (1,len(trainstd))
            
            # Normalize trainset and testset
            testmean = np.mean(svm_mat[train_ind,:],axis=0)
            testmean.shape = (1,len(testmean))
            teststd = np.std(svm_mat[train_ind,:],axis=0)
            teststd.shape = (1,len(teststd))

            trainset = np.divide((trainset - trainmean),trainstd)
            testset = np.divide((testset - testmean),teststd)

            inputs.append((trainset,testset,labels[train_ind],labels[test_ind]))
        
        subj_array_folds = np.delete(subj_array_folds,test_subjs)
        
    pool = mp.Pool(processes=nproc)
    scores = pool.map_async(_decoding,inputs).get()
    pool.close()
    pool.join()
    
#     subj_acc = np.zeros((len(subjects),))
#     scount = 0
#     i = 0
#     for subj in subjects:
#         subjmean = []
#         for cv in range(ncvs):
#             subjmean.append(scores[i])
#             i += 1
        
#         subj_acc[scount] = np.mean(subjmean)
        
#         scount += 1

#     return subj_acc

    acc = []
    for score in scores:
        acc.extend(score)
    return acc

def _decoding((trainset,testset,trainlabels,testlabels)):

#     clf = sklearn.linear_model.LogisticRegression()
    clf = svm.SVC(C=1.0, kernel='linear')

    clf.fit(trainset,trainlabels)
    predictions = clf.predict(testset)
    acc = predictions==testlabels
    
#     unique_cond = np.unique(trainlabels)
#     rdm = np.zeros((len(unique_cond),len(unique_cond)))
#     acc = []
#     for cond1 in unique_cond:
#         mismatches = []
#         prototype_ind = np.where(trainlabels==cond1)[0]
#         prototype = np.mean(trainset[prototype_ind,:],axis=0)
#         for cond2 in unique_cond:
#             test_ind = np.where(testlabels==cond2)[0]
#             test = np.mean(testset[test_ind,:],axis=0)
#             if cond1 == cond2: 
#                 correct = stats.pearsonr(prototype,test)[0]
#             else:
#                 mismatches.append(stats.pearsonr(prototype,test)[0])
        
#         if correct > np.max(mismatches): 
#             acc.append(1.0)
#         else:
#             acc.append(0.0)
    
    return acc

# %% [markdown]
# ## 1.1 Run across subject decoding on right-hand motor responses

# %%
actflow_data_rh.shape
# Out:
# (59412, 2, 96, 360)

# %%
nproc = 20
ncvs = 1

rois = np.where(networkdef==networkmappings['smn'])[0] + 1
rois = [9] # Left S1


sourceROIs = []
sourceROIs.extend(np.where(networkdef==networkmappings['fpn'])[0])
sourceROIs.extend(np.where(networkdef==networkmappings['dan'])[0])
sourceROIs.extend(np.where(networkdef==networkmappings['con'])[0])

distances_baseline_rh = np.zeros((nParcels,len(subjNums)*2))
for roi in sourceROIs:
    print 'Decoding roi', roi
    if roi in bad_rois: 
        continue

    distances_baseline_rh[roi,:] = motorResponseDecodings(stats.zscore(data_task_rh,axis=0), 
                                                          stats.zscore(actflow_data_rh[:,:,:,roi],axis=0),
                                                          rois=rois, ncvs=ncvs, nproc=nproc)
# Out:
# Decoding roi 13
# Decoding roi 14
# Decoding roi 28
# Decoding roi 62
# Decoding roi 72
# Decoding roi 76
# Decoding roi 79
# Decoding roi 81
# Decoding roi 82
# Decoding roi 84
# Decoding roi 88
# Decoding roi 90
# Decoding roi 91
# Decoding roi 96
# Decoding roi 97
# Decoding roi 110
# Decoding roi 132
# Decoding roi 143
# Decoding roi 144
# Decoding roi 148
# Decoding roi 169
# Decoding roi 170
# Decoding roi 193
# Decoding roi 194
# Decoding roi 208
# Decoding roi 237
# Decoding roi 241
# Decoding roi 242
# Decoding roi 252
# Decoding roi 253
# Decoding roi 256
# Decoding roi 259
# Decoding roi 260
# Decoding roi 262
# Decoding roi 264
# Decoding roi 268
# Decoding roi 270
# Decoding roi 271
# Decoding roi 272
# Decoding roi 276
# Decoding roi 277
# Decoding roi 290
# Decoding roi 312
# Decoding roi 323
# Decoding roi 324
# Decoding roi 328
# Decoding roi 341
# Decoding roi 349
# Decoding roi 350
# Decoding roi 356
# Decoding roi 10
# Decoding roi 45
# Decoding roi 49
# Decoding roi 94
# Decoding roi 95
# Decoding roi 115
# Decoding roi 116
# Decoding roi 126
# Decoding roi 135
# Decoding roi 136
# Decoding roi 142
# Decoding roi 145
# Decoding roi 225
# Decoding roi 229
# Decoding roi 274
# Decoding roi 275
# Decoding roi 295
# Decoding roi 296
# Decoding roi 306
# Decoding roi 315
# Decoding roi 316
# Decoding roi 322
# Decoding roi 325
# Decoding roi 9
# Decoding roi 36
# Decoding roi 37
# Decoding roi 42
# Decoding roi 43
# Decoding roi 44
# Decoding roi 56
# Decoding roi 57
# Decoding roi 58
# Decoding roi 59
# Decoding roi 77
# Decoding roi 83
# Decoding roi 85
# Decoding roi 98
# Decoding roi 104
# Decoding roi 105
# Decoding roi 107
# Decoding roi 108
# Decoding roi 112
# Decoding roi 113
# Decoding roi 146
# Decoding roi 147
# Decoding roi 166
# Decoding roi 168
# Decoding roi 177
# Decoding roi 178
# Decoding roi 179
# Decoding roi 189
# Decoding roi 190
# Decoding roi 204
# Decoding roi 216
# Decoding roi 217
# Decoding roi 222
# Decoding roi 223
# Decoding roi 224
# Decoding roi 236
# Decoding roi 238
# Decoding roi 239
# Decoding roi 257
# Decoding roi 261
# Decoding roi 263
# Decoding roi 265
# Decoding roi 278
# Decoding roi 284
# Decoding roi 285
# Decoding roi 287
# Decoding roi 288
# Decoding roi 292
# Decoding roi 293
# Decoding roi 326
# Decoding roi 327
# Decoding roi 346
# Decoding roi 348
# Decoding roi 357
# Decoding roi 358
# Decoding roi 359

# %% [markdown]
# ## 1.2 Compute statistics

# %%
statistics_rh = np.zeros((distances_baseline_rh.shape[0],3))
for roicount in range(distances_baseline_rh.shape[0]):
    ntrials = len(subjNums)*2
    p = stats.binom_test(np.mean(distances_baseline_rh[roicount,:])*ntrials,n=ntrials,p=0.5)
    if np.mean(distances_baseline_rh[roicount,:])>0.5:
        p = p/2.0
    else:
        p = 1.0-p/2.0

    statistics_rh[roicount,0] = np.mean(distances_baseline_rh[roicount,:])
    statistics_rh[roicount,1] = p

rois_testing = []
rois_testing.extend(np.where(networkdef==networkmappings['fpn'])[0])
rois_testing.extend(np.where(networkdef==networkmappings['con'])[0])
rois_testing.extend(np.where(networkdef==networkmappings['dan'])[0])
# rois_testing.extend(np.where(networkdef==networkmappings['dmn'])[0])
# rois_notSMN = np.where(networkdef!=networkmappings['smn'])[0]
rois_testing = np.asarray(rois_testing)
tmp = np.where(rois_testing>180)[0]
rois_testing = np.delete(rois_testing,tmp)

h0, qs = mc.fdrcorrection0(statistics_rh[rois_testing,1])
statistics_rh[:,1] = 1.0
i = 0
for roi in rois_testing:
    statistics_rh[roi,1] = qs[i]
    statistics_rh[roi,2] = h0[i]*statistics_rh[roi,0]
    i += 1
        
nSignificant = np.sum(statistics_rh[:,1] < 0.05)
print 'Number of significant transfers:', nSignificant

if nSignificant>0:
    sig_ind = np.where(statistics_rh[:,1]<0.05)[0]
    for ind in sig_ind:
        print '\tSignificant parcel:', ind+1
        print '\tAccuracy:', statistics_rh[ind,0]
        print '\tNetwork:', networkdef[ind]
print 'Network mappings:', networkmappings
# Out:
# Number of significant transfers: 0
# Network mappings: {'vis2': 2, 'lan': 6, 'vis1': 1, 'none2': 12, 'none1': 11, 'dan': 5, 'aud': 8, 'pmulti': 10, 'fpn': 7, 'dmn': 9, 'smn': 3, 'con': 4}

# %%
statistics_rh[147]
# Out:
# array([ 0.58333333,  0.36684792,  0.        ])

# %% [markdown]
# ## 1.1 Run across subject decoding on left-hand motor responses

# %%
nproc = 20
ncvs = 1

rois = np.where(networkdef==networkmappings['smn'])[0] + 1
rois = [189] # Right S1

sourceROIs = []
sourceROIs.extend(np.where(networkdef==networkmappings['fpn'])[0])
sourceROIs.extend(np.where(networkdef==networkmappings['dan'])[0])
sourceROIs.extend(np.where(networkdef==networkmappings['con'])[0])

distances_baseline_lh = np.zeros((nParcels,len(subjNums)*2))
for roi in sourceROIs:
    print 'Decoding roi', roi
    if roi in bad_rois: 
        continue

    distances_baseline_lh[roi,:] = motorResponseDecodings(stats.zscore(data_task_lh,axis=0), 
                                                          stats.zscore(actflow_data_lh[:,:,:,roi],axis=0),
                                                          rois=rois, ncvs=ncvs, nproc=nproc)
# Out:
# Decoding roi 13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-d1c280fe8ecc> in <module>()
#      18     distances_baseline_lh[roi,:] = motorResponseDecodings(stats.zscore(data_task_lh,axis=0),
#      19                                                           stats.zscore(actflow_data_lh[:,:,:,roi],axis=0),
# ---> 20                                                           rois=rois, ncvs=ncvs, nproc=nproc)
#      21
#
# ValueError: could not broadcast input array from shape (192) into shape (384)

# %% [markdown]
# ## 1.2 Compute statistics

# %%
statistics_lh = np.zeros((distances_baseline_lh.shape[0],3))
for roicount in range(distances_baseline_lh.shape[0]):
    ntrials = len(subjNums)*2
    p = stats.binom_test(np.mean(distances_baseline_lh[roicount,:])*ntrials,n=ntrials,p=0.5)
    if np.mean(distances_baseline_lh[roicount,:])>0.5:
        p = p/2.0
    else:
        p = 1.0-p/2.0

    statistics_lh[roicount,0] = np.mean(distances_baseline_lh[roicount,:])
    statistics_lh[roicount,1] = p

rois_testing = []
rois_testing.extend(np.where(networkdef==networkmappings['fpn'])[0])
rois_testing.extend(np.where(networkdef==networkmappings['con'])[0])
rois_testing.extend(np.where(networkdef==networkmappings['dan'])[0])
# rois_notSMN = np.where(networkdef!=networkmappings['smn'])[0]
h0, qs = mc.fdrcorrection0(statistics_lh[rois_testing,1])
statistics_lh[:,1] = 1.0
i = 0
for roi in rois_testing:
    statistics_lh[roi,1] = qs[i]
    statistics_lh[roi,2] = h0[i]*statistics_lh[roi,0]
    i += 1
        
nSignificant = np.sum(statistics_lh[:,1] < 0.05)
print 'Number of significant transfers:', nSignificant

if nSignificant>0:
    sig_ind = np.where(statistics_lh[:,1]<0.05)[0]
    for ind in sig_ind:
        print '\tSignificant parcel:', ind+1
        print '\tAccuracy:', statistics_lh[ind,0]
        print '\tNetwork:', networkdef[ind]
print 'Network mappings:', networkmappings
