# %% [markdown]
# # Taku Ito
# ## 12/12/2018
#
# ## Compute Ridge FC using cross-subject cross-validation
#
# ## Using Alex Huth's implementation for faster computation, maximizing predicted and actual responses of target variable

# %%
import numpy as np
import nibabel as nib
import os
import matplotlib.pyplot as plt
# %matplotlib inline
os.sys.path.append('ridge/')
import ridge
import seaborn as sns
import h5py
os.environ['OMP_NUM_THREADS'] = str(1)
import multiprocessing as mp
import scipy.stats as stats
import time
from sklearn.linear_model import Ridge

sns.set_style("white")
plt.rcParams["font.family"] = "FreeSans"

# %%
# Excluding 084
subjNums = ['013','014','016','017','018','021','023','024','026','027','028','030','031','032','033',
            '034','035','037','038','039','040','041','042','043','045','046','047','048','049','050',
            '053','055','056','057','058','062','063','066','067','068','069','070','072','074','075',
            '076','077','081','085','086','087','088','090','092','093','094','095','097','098','099',
            '101','102','103','104','105','106','108','109','110','111','112','114','115','117','119',
            '120','121','122','123','124','125','126','127','128','129','130','131','132','134','135',
            '136','137','138','139','140','141']



basedir = '/projects3/SRActFlow/'

# Using final partition
networkdef = np.loadtxt('/projects3/NetworkDiversity/data/network_partition.txt')
networkorder = np.asarray(sorted(range(len(networkdef)), key=lambda k: networkdef[k]))
networkorder.shape = (len(networkorder),1)
# network mappings for final partition set
networkmappings = {'fpn':7, 'vis1':1, 'vis2':2, 'smn':3, 'aud':8, 'lan':6, 'dan':5, 'con':4, 'dmn':9, 
                   'pmulti':10, 'none1':11, 'none2':12}
networks = networkmappings.keys()

xticks = {}
reorderednetworkaffil = networkdef[networkorder]
for net in networks:
    netNum = networkmappings[net]
    netind = np.where(reorderednetworkaffil==netNum)[0]
    tick = np.max(netind)
    xticks[tick] = net

## General parameters/variables
nParcels = 360
nSubjs = len(subjNums)

glasserfile2 = '/projects/AnalysisTools/ParcelsGlasser2016/Q1-Q6_RelatedParcellation210.LR.CorticalAreas_dil_Colors.32k_fs_RL.dlabel.nii'
glasser2 = nib.load(glasserfile2).get_data()
glasser2 = np.squeeze(glasser2)

sortednets = np.sort(xticks.keys())
orderednetworks = []
for net in sortednets: orderednetworks.append(xticks[net])
    
networkpalette = ['royalblue','slateblue','paleturquoise','darkorchid','limegreen',
                  'lightseagreen','yellow','orchid','r','peru','orange','olivedrab']
networkpalette = np.asarray(networkpalette)

OrderedNetworks = ['VIS1','VIS2','SMN','CON','DAN','LAN','FPN','AUD','DMN','PMM','VMM','ORA']

# %% [markdown]
# # Load resting-state data

# %%
def loadRestActivity(subj,model='24pXaCompCorXVolterra',zscore=False):
    
    datadir = basedir + 'data/postProcessing/hcpPostProcCiric/'
    h5f = h5py.File(datadir + subj + '_glmOutput_data.h5','r')
    data = h5f['Rest1/nuisanceReg_resid_24pXaCompCorXVolterra'][:].copy()
    h5f.close()
    
    if zscore:
        data = stats.zscore(data,axis=1)
    return data

def loadMask(roi,dilated=True):
    maskdir = basedir + 'data/results/surfaceMasks/'
    if dilated:
        maskfile = maskdir + 'GlasserParcel' + str(roi) + '_dilated_10mm.dscalar.nii'
    else:
        maskfile = maskdir + 'GlasserParcel' + str(roi) + '.dscalar.nii'
    maskdata = np.squeeze(nib.load(maskfile).get_data())
    return maskdata

def ridgeCorrWrapper((sourceTrain,sourceTest,targetTrain,targetTest)):
    rcorr = ridge.ridge_corr(sourceTrain,sourceTest,targetTrain,targetTest,alphas=np.logspace(0,4,20))
#     rcorr = []
#     alpha = np.logspace(0,4,20)
#     for a in alpha:
# #         print 'start prediction'
#         clf = Ridge(alpha=a)
#         clf.fit(sourceTrain,targetTrain)
#         predictY = clf.predict(sourceTest)
# #         print 'finished prediction'
#         rvalues = np.mean(np.multiply(stats.zscore(predictY,axis=0),stats.zscore(targetTest,axis=0)),axis=0)
# #         print 'correlation calculation'
#         rcorr.append(rvalues)
        
    return rcorr

def ridgeWrapper((stim,resp,alpha)):
#     wt = ridge.ridge.ridge(stim,resp,alpha)
    clf = Ridge(alpha=alpha)
    clf.fit(stim,resp)
    wt = clf.coef_

    return wt

# %% [markdown]
# # Modified orig approach

# %%
# Run for LEFT motor cortex
roi = 189 # Which ROI's FC do we want to predict
zscore = True
nboots = 10 # Will run these bootstraps in parallel
alphas = np.zeros((glasser2.shape[0],nboots))
scount = 0
rcorrs = []
for subj in subjNums:
    newSubjs = np.delete(subjNums,scount)
    subjData = loadRestActivity(subj,zscore=zscore)
    
    # Load dilated ROI mask
    mask = loadMask(roi,dilated=True)
    # Find vertices outside dilated mask (source data)
    source_ind = np.where(mask==0)[0]
    sourceTest = subjData[source_ind,:].copy()
    
    # Now load regular mask to identify responses/activities we want to predict (target data)
    mask = loadMask(roi,dilated=False)
    target_ind = np.where(mask)[0]
    targetTest = subjData[target_ind,:].copy()
    
    # Now find train subjects
    print 'Loading bootstrapped training data for subject', subj
    trainSubjs = np.random.choice(subjNums,nboots,replace=False) # No replacement
    inputs = []
    for trainsubj in trainSubjs:
        subjData = loadRestActivity(trainsubj,zscore=zscore)
        sourceTrain = subjData[source_ind,:].copy()
        targetTrain = subjData[target_ind,:].copy()
        inputs.append((sourceTrain.T,sourceTest.T,targetTrain.T,targetTest.T))
    
    del subjData
    os.environ['OMP_NUM_THREADS'] = str(2)

    
    print '\tBeginning regression/cross-validation'
    before = time.time()
    pool = mp.Pool(processes=nboots)
    rcorr = pool.map_async(ridgeCorrWrapper,inputs).get()
    pool.close()
    pool.join()
    
    del inputs, pool
    
    after = time.time()
    print '\tTime for regression for one subject:', after-before
    
    # Get average alphas across bootstrap
    rcorr_avg = np.mean(np.asarray(rcorr),axis=0)
    rcorrs.append(rcorr_avg)
    
    scount += 1
# Out:
# Loading bootstrapped training data for subject 013
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 146.652105093
# Loading bootstrapped training data for subject 014
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 128.381666899
# Loading bootstrapped training data for subject 016
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 138.695076942
# Loading bootstrapped training data for subject 017
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 136.767871857
# Loading bootstrapped training data for subject 018
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 138.175825119
# Loading bootstrapped training data for subject 021
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 132.624850988
# Loading bootstrapped training data for subject 023
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 142.599781036
# Loading bootstrapped training data for subject 024
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 144.555227995
# Loading bootstrapped training data for subject 026
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 124.428408146
# Loading bootstrapped training data for subject 027
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 194.550369024
# Loading bootstrapped training data for subject 028
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 148.796601057
# Loading bootstrapped training data for subject 030
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 145.198331833
# Loading bootstrapped training data for subject 031
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 143.02676487
# Loading bootstrapped training data for subject 032
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 149.116980076
# Loading bootstrapped training data for subject 033
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 149.11640501
# Loading bootstrapped training data for subject 034
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 146.368488073
# Loading bootstrapped training data for subject 035
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 155.7826159
# Loading bootstrapped training data for subject 037
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 141.152724981
# Loading bootstrapped training data for subject 038
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 139.760408163
# Loading bootstrapped training data for subject 039
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 144.248219967
# Loading bootstrapped training data for subject 040
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 146.991168976
# Loading bootstrapped training data for subject 041
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 146.961313009
# Loading bootstrapped training data for subject 042
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 135.188405037
# Loading bootstrapped training data for subject 043
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 145.527019024
# Loading bootstrapped training data for subject 045
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 145.495941162
# Loading bootstrapped training data for subject 046
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 143.095668077
# Loading bootstrapped training data for subject 047
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 145.706875086
# Loading bootstrapped training data for subject 048
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 149.75007987
# Loading bootstrapped training data for subject 049
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 142.300839901
# Loading bootstrapped training data for subject 050
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 157.56468606
# Loading bootstrapped training data for subject 053
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 149.119535208
# Loading bootstrapped training data for subject 055
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 141.005537987
# Loading bootstrapped training data for subject 056
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 155.803432941
# Loading bootstrapped training data for subject 057
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 143.566280842
# Loading bootstrapped training data for subject 058
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 150.316776991
# Loading bootstrapped training data for subject 062
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 146.716325998
# Loading bootstrapped training data for subject 063
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 149.012346983
# Loading bootstrapped training data for subject 066
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 147.345185995
# Loading bootstrapped training data for subject 067
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 145.76351285
# Loading bootstrapped training data for subject 068
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 143.101612806
# Loading bootstrapped training data for subject 069
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 145.723569155
# Loading bootstrapped training data for subject 070
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 151.848267078
# Loading bootstrapped training data for subject 072
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 150.625565052
# Loading bootstrapped training data for subject 074
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 151.791123152
# Loading bootstrapped training data for subject 075
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 152.287405968
# Loading bootstrapped training data for subject 076
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 158.794940948
# Loading bootstrapped training data for subject 077
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 144.666990042
# Loading bootstrapped training data for subject 081
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 154.084614038
# Loading bootstrapped training data for subject 085
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 157.767980099
# Loading bootstrapped training data for subject 086
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 148.822234154
# Loading bootstrapped training data for subject 087
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 166.618220091
# Loading bootstrapped training data for subject 088
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 143.606197119
# Loading bootstrapped training data for subject 090
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 167.767539024
# Loading bootstrapped training data for subject 092
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 157.509803772
# Loading bootstrapped training data for subject 093
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 213.091668844
# Loading bootstrapped training data for subject 094
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 198.140727997
# Loading bootstrapped training data for subject 095
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 171.30073595
# Loading bootstrapped training data for subject 097
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 160.545791149
# Loading bootstrapped training data for subject 098
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 165.423410892
# Loading bootstrapped training data for subject 099
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 167.330358028
# Loading bootstrapped training data for subject 101
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 153.385577917
# Loading bootstrapped training data for subject 102
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 164.815129042
# Loading bootstrapped training data for subject 103
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 222.928460836
# Loading bootstrapped training data for subject 104
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 157.643975973
# Loading bootstrapped training data for subject 105
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 160.837065935
# Loading bootstrapped training data for subject 106
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 194.873594999
# Loading bootstrapped training data for subject 108
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 179.147284985
# Loading bootstrapped training data for subject 109
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 141.863341093
# Loading bootstrapped training data for subject 110
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 148.673979998
# Loading bootstrapped training data for subject 111
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 165.194628954
# Loading bootstrapped training data for subject 112
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 164.241539001
# Loading bootstrapped training data for subject 114
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 159.042451859
# Loading bootstrapped training data for subject 115
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 175.907441139
# Loading bootstrapped training data for subject 117
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 165.284373045
# Loading bootstrapped training data for subject 119
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 176.502590179
# Loading bootstrapped training data for subject 120
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 155.229545832
# Loading bootstrapped training data for subject 121
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 159.319216013
# Loading bootstrapped training data for subject 122
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 164.697299004
# Loading bootstrapped training data for subject 123
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 166.613210917
# Loading bootstrapped training data for subject 124
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 165.886266947
# Loading bootstrapped training data for subject 125
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 182.642580032
# Loading bootstrapped training data for subject 126
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 200.861258984
# Loading bootstrapped training data for subject 127
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 182.112720013
# Loading bootstrapped training data for subject 128
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 182.299262047
# Loading bootstrapped training data for subject 129
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 191.010848999
# Loading bootstrapped training data for subject 130
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 178.277598858
# Loading bootstrapped training data for subject 131
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 166.682769775
# Loading bootstrapped training data for subject 132
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 190.61582303
# Loading bootstrapped training data for subject 134
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 182.438870192
# Loading bootstrapped training data for subject 135
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 172.378031969
# Loading bootstrapped training data for subject 136
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 156.535317898
# Loading bootstrapped training data for subject 137
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 146.634327888
# Loading bootstrapped training data for subject 138
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 143.239875078
# Loading bootstrapped training data for subject 139
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 142.808007002
# Loading bootstrapped training data for subject 140
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 147.642620087
# Loading bootstrapped training data for subject 141
# 	Beginning regression/cross-validation
# 	Time for regression for one subject: 138.217535019

# %% [markdown]
# # Find best alphas for each vertex, across subjects

# %%
# This will be an alphas X Vertices matrix
group_average_alphas = np.mean(np.asarray(rcorrs),axis=0)
max_alphas_ind = group_average_alphas.argmax(axis=0)

# Now for each vertex, identify the best alpha
alpha_by_vertex = np.zeros(max_alphas_ind.shape)
for vertex in range(max_alphas_ind.shape[0]):
    alpha_by_vertex[vertex] = np.logspace(0,4,20)[max_alphas_ind[vertex]]

# %% [markdown]
# # Save to disk group penalty terms (alphas) for each vertex

# %%
ridgefcdir = '/projects3/SRActFlow/data/results/ridgeFC/'
h5f = h5py.File(ridgefcdir + 'TargetParcel' + str(roi) + '_RidgeFC.h5','a')
# First save out penalty alphas for each vertex
try:
    h5f.create_dataset('alphasPerVertex',data=alpha_by_vertex)
except:
    del h5f['alphasPerVertex']
    h5f.create_dataset('alphasPerVertex',data=alpha_by_vertex)
h5f.close()

# ridgefcdir = '/projects3/SRActFlow/data/results/ridgeFC/'
# h5f = h5py.File(ridgefcdir + 'TargetParcel' + str(roi) + '_RidgeFC.h5','r')
# alpha_by_vertex = h5f['alphasPerVertex'][:].copy()
# h5f.close()

# %% [markdown]
# # Now for each subject fit the regression model using the optimized penalty term (alpha), and save to disk

# %%
ridgefcdir = '/projects3/SRActFlow/data/results/ridgeFC/'

nproc = 20
for subj in subjNums:
    print 'Subject', subj
    print '\tLoading data...'
    subjData = loadRestActivity(subj,zscore=False)
    
    # Load dilated ROI mask
    mask = loadMask(roi,dilated=True)
    # Find vertices outside dilated mask (source data)
    source_ind = np.where(mask==0)[0]
    sourceData = subjData[source_ind,:].copy()
    
    # Now load regular mask to identify responses/activities we want to predict (target data)
    mask = loadMask(roi,dilated=False)
    target_ind = np.where(mask)[0]
    targetData = subjData[target_ind,:].copy()
    
#     inputs = []
#     i = 0
#     for target in target_ind[:20]:
#         target_data = subjData[target,:].copy()
#         target_data.shape = (len(target_data),1)
#         inputs.append((sourceData.T,target_data,alpha_by_vertex[i]))
#         i += 1
    
#     print '\tRunning source to target ridge regression,', nproc, 'vertices in parallel'
#     pool = mp.Pool(processes=nproc)
#     sourceCoefs = pool.map_async(ridgeWrapper,inputs).get()
#     pool.close()
#     pool.join()
#     sourceToTargetMappings = np.asarray(sourceCoefs)

    print '\tRunning source to target ridge regression using', nproc, 'processes'
    os.environ['OMP_NUM_THREADS'] = str(nproc)

    clf = Ridge(alpha=alpha_by_vertex)
    clf.fit(sourceData.T,targetData.T)
    sourceToTargetMappings = clf.coef_
    
    # All vertices to target indices (makes it easier for comparison)
    sourceToTargetMappings2 = np.zeros((len(glasser2),len(target_ind)))
    sourceToTargetMappings2[source_ind,:] = sourceToTargetMappings.T
    
    # Save out to file
    print '\tSaving out to disk'
    h5f = h5py.File(ridgefcdir + 'TargetParcel' + str(roi) + '_RidgeFC.h5','a')
    try:
        h5f.create_dataset(subj + '/sourceToTargetMapping',data=sourceToTargetMappings2)
    except:
        del h5f[subj+'/sourceToTargetMapping']
        h5f.create_dataset(subj + '/sourceToTargetMapping',data=sourceToTargetMappings2)
    h5f.close()
    
    del sourceToTargetMappings2, sourceToTargetMappings
# Out:
# Subject 013
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 014
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 016
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 017
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 018
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 021
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 023
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 024
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 026
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 027
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 028
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 030
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 031
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 032
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 033
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 034
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 035
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 037
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 038
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 039
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 040
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 041
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 042
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 043
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 045
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 046
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 047
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 048
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 049
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 050
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 053
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 055
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 056
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 057
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 058
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 062
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 063
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 066
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 067
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 068
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 069
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 070
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 072
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 074
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 075
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 076
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 077
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 081
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 085
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 086
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 087
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 088
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 090
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 092
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 093
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 094
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 095
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 097
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 098
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 099
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 101
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 102
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 103
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 104
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 105
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 106
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 108
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 109
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 110
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 111
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 112
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 114
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 115
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 117
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 119
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 120
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 121
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 122
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 123
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 124
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 125
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 126
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 127
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 128
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 129
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 130
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 131
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 132
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 134
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 135
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 136
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 137
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 138
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 139
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 140
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk
# Subject 141
# 	Loading data...
# 	Running source to target ridge regression using 20 processes
# 	Saving out to disk

# %% [markdown]
# # Remove 'collider' FC coefficients
#
# #### Go through each negative connection and see if there's also a negative correlation-based FC for that connection. If not, then set that connection to 0.
# #### Probably should do the same for positive correlations

# %%
def testIfCollider((ridgecoef,sourceTS,targetTS)):
    """
    ridgecoef - an array of all source vertices ridge FC coefficients
    sourceTS - a space X time time series of all source vertices
    targetTS - a 1d array time series of the target time series vertices
    """
    ind = np.where(ridgecoef<0)[0]
    
    # Compute correlation in a vectorized manner
    corr = np.mean(np.multiply(stats.zscore(sourceTS[ind,:],axis=1),stats.zscore(targetTS)))
    
    # For the length of this time series (1065), a significant correlation will exceed np.abs(.06)
    correlation_thresh = -0.06 # Manually looked this up
    # If the actual correlation is not negative/not significant, then set it to 0
    collider_ind = np.where(corr>correlation_thresh)[0]
    
    if len(collider_ind)>0:
        ridgecoef[collider_ind] = 0

    return ridgecoef

# %%
nproc = 20
ridgefcdir = '/projects3/SRActFlow/data/results/ridgeFC/'

targetROIs = [9,189]
for subj in subjNums:
    subjData = loadRestActivity(subj,zscore=False)
    print 'Removing colliders, subject', subj
    for roi in targetROIs:
        print '\tROI', roi
        h5f = h5py.File(ridgefcdir + 'TargetParcel' + str(roi) + '_RidgeFC.h5','r')
        ridgefc = h5f[subj + '/sourceToTargetMapping'][:].copy()
        h5f.close()
                
        target_ind = np.where(glasser2==roi)[0]
        
        # Load dilated ROI mask
        mask = loadMask(roi,dilated=True)
        # Find vertices outside dilated mask (source data)
        source_ind = np.where(mask==0)[0]
        sourceData = subjData[source_ind,:].copy()
        
        inputs = []
        results = []
        target_count = 0
        for target_vertex in target_ind:
#             inputs.append((ridgefc[source_ind,target_count],subjData[source_ind,:],subjData[target_vertex,:]))
            if target_count%100==0: 
                print '\tRemoving colliders for target vertex', target_count, '/', len(target_ind)
#             if target_count%(nproc-1)==0:
#                 pool = mp.Pool(processes=nproc)
#                 results.extend(pool.map_async(testIfCollider,inputs).get())
#                 pool.close()
#                 pool.join()
                
#                 del inputs
#                 inputs = []

            ridgefc[source_ind,target_count] = testIfCollider((ridgefc[source_ind,target_count],subjData[source_ind,:],subjData[target_vertex,:]))
                        
            target_count += 1
        

        
#         target_count = 0
#         for target_vertex in target_ind:
#             ridgefc[source_ind,target_count] = results[target_count]
#             target_count += 1
            
                
        h5f = h5py.File(ridgefcdir + 'TargetParcel' + str(roi) + '_RidgeFC_NoColliders.h5','a')
        try:
            h5f.create_dataset(subj + '/sourceToTargetMapping',data=ridgefc)
        except:
            del h5f[subj+'/sourceToTargetMapping']
            h5f.create_dataset(subj + '/sourceToTargetMapping',data=ridgefc)
        h5f.close()
# Out:
# Removing colliders, subject 013
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 014
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 016
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 017
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 018
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 021
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 023
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 024
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 026
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 027
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 028
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 030
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 031
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 032
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 033
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 034
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 035
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 037
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 038
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 039
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 040
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 041
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 042
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 043
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 045
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 046
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 047
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 048
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 049
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 050
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 053
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 055
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 056
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 057
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 058
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 062
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 063
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 066
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 067
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 068
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 069
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 070
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 072
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 074
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 075
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 076
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 077
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 081
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 085
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 086
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 087
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 088
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 090
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 092
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 093
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 094
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 095
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 097
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 098
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 099
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 101
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 102
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 103
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 104
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 105
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 106
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 108
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 109
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 110
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 111
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 112
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 114
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 115
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 117
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 119
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 120
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 121
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 122
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 123
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 124
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 125
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 126
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 127
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 128
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 129
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 130
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 131
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 132
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 134
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 135
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 136
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 137
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 138
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 139
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 140
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
# Removing colliders, subject 141
# 	ROI 9
# 	Removing colliders for target vertex 0 / 563
# 	Removing colliders for target vertex 100 / 563
# 	Removing colliders for target vertex 200 / 563
# 	Removing colliders for target vertex 300 / 563
# 	Removing colliders for target vertex 400 / 563
# 	Removing colliders for target vertex 500 / 563
# 	ROI 189
# 	Removing colliders for target vertex 0 / 540
# 	Removing colliders for target vertex 100 / 540
# 	Removing colliders for target vertex 200 / 540
# 	Removing colliders for target vertex 300 / 540
# 	Removing colliders for target vertex 400 / 540
# 	Removing colliders for target vertex 500 / 540
