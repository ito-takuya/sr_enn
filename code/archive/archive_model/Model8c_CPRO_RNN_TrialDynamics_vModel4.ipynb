# %% [markdown]
# # Model2 - RNN model of CPRO task using PyTorch with Trial dynamics
#
# #### Taku Ito
# #### 09/30/2018

# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
np.set_printoptions(suppress=True)
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
# %matplotlib inline
import os
import model.model4 as model
model = reload(model)
import model.task as task
task = reload(task)
import time
os.sys.path.append('utils/bctpy/')
import bct
retrain = True

# %% [markdown]
# # Build training and test batches

# %%
model = reload(model)
TrialInfo = model.TrialBatches()
TrialInfo.createAllBatches(nproc=25)
# Out:
# Running batch 0
# Running batch 1500
# Running batch 3000
# Running batch 4500
# Running batch 6000
# Running batch 7500
# Running batch 9000
# Running batch 10500
# Running batch 12000
# Running batch 13500
# Running batch 15000
# Running batch 16500
# Running batch 18000
# Running batch 19500
# Running batch 21000
# Running batch 22500
# Running batch 24000
# Running batch 25500
# Running batch 28500
# Running batch 27000
# Running batch 30000
# Running batch 33000
# Running batch 31500
# Running batch 34500
# Running batch 36000
# Running batch 27100
# Running batch 28600
# Running batch 25600
# Running batch 10600
# Running batch 18100
# Running batch 24100
# Running batch 100
# Running batch 31600
# Running batch 36100
# Running batch 21100
# Running batch 15100
# Running batch 30100
# Running batch 33100
# Running batch 16600
# Running batch 7600
# Running batch 3100
# Running batch 6100
# Running batch 12100
# Running batch 19600
# Running batch 13600
# Running batch 34600
# Running batch 1600
# Running batch 22600
# Running batch 9100
# Running batch 4600
# Running batch 27200
# Running batch 18200
# Running batch 28700
# Running batch 10700
# Running batch 25700
# Running batch 36200
# Running batch 33200
# Running batch 15200
# Running batch 12200
# Running batch 21200
# Running batch 24200
# Running batch 16700
# Running batch 31700
# Running batch 19700
# Running batch 200
# Running batch 13700
# Running batch 22700
# Running batch 3200
# Running batch 6200
# Running batch 9200
# Running batch 4700
# Running batch 1700
# Running batch 7700
# Running batch 34700
# Running batch 30200
# Running batch 27300
# Running batch 18300
# Running batch 28800
# Running batch 10800
# Running batch 25800
# Running batch 33300
# Running batch 12300
# Running batch 31800
# Running batch 24300
# Running batch 16800
# Running batch 19800
# Running batch 15300
# Running batch 21300
# Running batch 300
# Running batch 13800
# Running batch 6300
# Running batch 4800
# Running batch 34800
# Running batch 36300
# Running batch 22800
# Running batch 1800
# Running batch 7800
# Running batch 30300
# Running batch 9300
# Running batch 27400
# Running batch 3300
# Running batch 18400
# Running batch 28900
# Running batch 25900
# Running batch 10900
# Running batch 24400
# Running batch 12400
# Running batch 16900
# Running batch 19900
# Running batch 33400
# Running batch 21400
# Running batch 400
# Running batch 15400
# Running batch 31900
# Running batch 34900
# Running batch 13900
# Running batch 27500
# Running batch 30400
# Running batch 7900
# Running batch 36400
# Running batch 4900
# Running batch 1900
# Running batch 3400
# Running batch 6400
# Running batch 29000
# Running batch 22900
# Running batch 18500
# Running batch 26000
# Running batch 9400
# Running batch 11000
# Running batch 24500
# Running batch 12500
# Running batch 17000
# Running batch 21500
# Running batch 20000
# Running batch 32000
# Running batch 33500
# Running batch 500
# Running batch 27600
# Running batch 35000
# Running batch 14000
# Running batch 29100
# Running batch 8000
# Running batch 26100
# Running batch 30500
# Running batch 6500
# Running batch 18600
# Running batch 3500
# Running batch 23000
# Running batch 9500
# Running batch 11100
# Running batch 15500
# Running batch 5000
# Running batch 2000
# Running batch 12600
# Running batch 24600
# Running batch 36500
# Running batch 17100
# Running batch 32100
# Running batch 21600
# Running batch 600
# Running batch 20100
# Running batch 27700
# Running batch 33600
# Running batch 14100
# Running batch 29200
# Running batch 35100
# Running batch 30600
# Running batch 26200
# Running batch 18700
# Running batch 8100
# Running batch 23100
# Running batch 11200
# Running batch 5100
# Running batch 3600
# Running batch 32200
# Running batch 24700
# Running batch 12700
# Running batch 17200
# Running batch 6600
# Running batch 21700
# Running batch 20200
# Running batch 700
# Running batch 27800
# Running batch 2100
# Running batch 15600
# Running batch 9600
# Running batch 33700
# Running batch 29300
# Running batch 14200
# Running batch 36600
# Running batch 26300
# Running batch 18800
# Running batch 35200
# Running batch 30700
# Running batch 11300
# Running batch 32300
# Running batch 17300
# Running batch 20300
# Running batch 23200
# Running batch 24800
# Running batch 8200
# Running batch 27900
# Running batch 5200
# Running batch 12800
# Running batch 21800
# Running batch 3700
# Running batch 15700
# Running batch 6700
# Running batch 800
# Running batch 29400
# Running batch 36700
# Running batch 18900
# Running batch 9700
# Running batch 2200
# Running batch 33800
# Running batch 26400
# Running batch 14300
# Running batch 30800
# Running batch 17400
# Running batch 35300
# Running batch 24900
# Running batch 11400
# Running batch 20400
# Running batch 32400
# Running batch 28000
# Running batch 21900
# Running batch 5300
# Running batch 29500
# Running batch 12900
# Running batch 15800
# Running batch 900
# Running batch 3800
# Running batch 23300
# Running batch 6800
# Running batch 8300
# Running batch 9800
# Running batch 19000
# Running batch 33900
# Running batch 36800
# Running batch 26500
# Running batch 2300
# Running batch 17500
# Running batch 25000
# Running batch 11500
# Running batch 28100
# Running batch 22000
# Running batch 20500
# Running batch 13000
# Running batch 14400
# Running batch 29600
# Running batch 1000
# Running batch 15900
# Running batch 35400
# Running batch 32500
# Running batch 30900
# Running batch 6900
# Running batch 3900
# Running batch 19100
# Running batch 34000
# Running batch 36900
# Running batch 9900
# Running batch 5400
# Running batch 26600
# Running batch 2400
# Running batch 17600
# Running batch 23400
# Running batch 8400
# Running batch 25100
# Running batch 11600
# Running batch 28200
# Running batch 13100
# Running batch 29700
# Running batch 1100
# Running batch 32600
# Running batch 16000
# Running batch 22100
# Running batch 14500
# Running batch 35500
# Running batch 20600
# Running batch 31000
# Running batch 34100
# Running batch 37000
# Running batch 19200
# Running batch 4000
# Running batch 26700
# Running batch 17700
# Running batch 10000
# Running batch 7000
# Running batch 25200
# Running batch 23500
# Running batch 11700
# Running batch 13200
# Running batch 8500
# Running batch 2500
# Running batch 28300
# Running batch 5500
# Running batch 1200
# Running batch 29800
# Running batch 35600
# Running batch 32700
# Running batch 22200
# Running batch 20700
# Running batch 14600
# Running batch 34200
# Running batch 19300
# Running batch 16100
# Running batch 17800
# Running batch 31100
# Running batch 37100
# Running batch 23600
# Running batch 26800
# Running batch 13300
# Running batch 28400
# Running batch 25300
# Running batch 11800
# Running batch 10100
# Running batch 8600
# Running batch 1300
# Running batch 4100
# Running batch 7100
# Running batch 5600
# Running batch 29900
# Running batch 32800
# Running batch 22300
# Running batch 35700
# Running batch 20800
# Running batch 2600
# Running batch 19400
# Running batch 14700
# Running batch 34300
# Running batch 37200
# Running batch 16200
# Running batch 17900
# Running batch 26900
# Running batch 37500
# Running batch 25400
# Running batch 11900
# Running batch 10200
# Running batch 39000
# Running batch 13400
# Running batch 31200
# Running batch 22400
# Running batch 5700
# Running batch 23700
# Running batch 1400
# Running batch 7200
# Running batch 8700
# Running batch 20900
# Running batch 35800
# Running batch 32900
# Running batch 4200
# Running batch 2700
# Running batch 14800
# Running batch 40500
# Running batch 42000
# Running batch 34400
# Running batch 37600
# Running batch 37300
# Running batch 10300
# Running batch 43500
# Running batch 45000
# Running batch 16300
# Running batch 46500
# Running batch 39100
# Running batch 23800
# Running batch 7300
# Running batch 5800
# Running batch 48000
# Running batch 49500
# Running batch 35900
# Running batch 8800
# Running batch 51000
# Running batch 52500
# Running batch 31300
# Running batch 54000
# Running batch 2800
# Running batch 4300
# Running batch 40600
# Running batch 14900
# Running batch 42100
# Running batch 43600
# Running batch 55500
# Running batch 45100
# Running batch 10400
# Running batch 37700
# Running batch 39200
# Running batch 16400
# Running batch 23900
# Running batch 5900
# Running batch 46600
# Running batch 49600
# Running batch 48100
# Running batch 7400
# Running batch 37400
# Running batch 57000
# Running batch 52600
# Running batch 51100
# Running batch 31400
# Running batch 4400
# Running batch 54100
# Running batch 8900
# Running batch 2900
# Running batch 40700
# Running batch 55600
# Running batch 45200
# Running batch 42200
# Running batch 43700
# Running batch 58500
# Running batch 37800
# Running batch 39300
# Running batch 46700
# Running batch 60000
# Running batch 61500
# Running batch 63000
# Running batch 64500
# Running batch 66000
# Running batch 49700
# Running batch 67500
# Running batch 52700
# Running batch 48200
# Running batch 57100
# Running batch 54200
# Running batch 69000
# Running batch 70500
# Running batch 72000
# Running batch 73500
# Running batch 51200
# Running batch 42300
# Running batch 55700
# Running batch 43800
# Running batch 39400
# Running batch 45300
# Running batch 37900
# Running batch 40800
# Running batch 58600
# Running batch 64600
# Running batch 46800
# Running batch 61600
# Running batch 63100
# Running batch 49800
# Running batch 52800
# Running batch 66100
# Running batch 57200
# Running batch 48300
# Running batch 67600
# Running batch 60100
# Running batch 54300
# Running batch 70600
# Running batch 69100
# Running batch 72100
# Running batch 43900
# Running batch 42400
# Running batch 51300
# Running batch 73600
# Running batch 45400
# Running batch 38000
# Running batch 58700
# Running batch 40900
# Running batch 39500
# Running batch 46900
# Running batch 49900
# Running batch 64700
# Running batch 61700
# Running batch 63200
# Running batch 52900
# Running batch 55800
# Running batch 57300
# Running batch 67700
# Running batch 70700
# Running batch 44000
# Running batch 66200
# Running batch 54400
# Running batch 48400
# Running batch 42500
# Running batch 69200
# Running batch 45500
# Running batch 72200
# Running batch 73700
# Running batch 38100
# Running batch 51400
# Running batch 60200
# Running batch 41000
# Running batch 39600
# Running batch 47000
# Running batch 50000
# Running batch 64800
# Running batch 58800
# Running batch 61800
# Running batch 57400
# Running batch 53000
# Running batch 55900
# Running batch 63300
# Running batch 67800
# Running batch 70800
# Running batch 44100
# Running batch 42600
# Running batch 66300
# Running batch 45600
# Running batch 48500
# Running batch 54500
# Running batch 41100
# Running batch 51500
# Running batch 47100
# Running batch 69300
# Running batch 38200
# Running batch 50100
# Running batch 39700
# Running batch 73800
# Running batch 60300
# Running batch 57500
# Running batch 53100
# Running batch 56000
# Running batch 72300
# Running batch 64900
# Running batch 63400
# Running batch 61900
# Running batch 67900
# Running batch 58900
# Running batch 44200
# Running batch 45700
# Running batch 70900
# Running batch 48600
# Running batch 41200
# Running batch 54600
# Running batch 47200
# Running batch 51600
# Running batch 42700
# Running batch 38300
# Running batch 66400
# Running batch 50200
# Running batch 69400
# Running batch 57600
# Running batch 39800
# Running batch 60400
# Running batch 56100
# Running batch 73900
# Running batch 53200
# Running batch 68000
# Running batch 65000
# Running batch 72400
# Running batch 63500
# Running batch 62000
# Running batch 59000
# Running batch 44300
# Running batch 45800
# Running batch 41300
# Running batch 71000
# Running batch 47300
# Running batch 51700
# Running batch 48700
# Running batch 42800
# Running batch 57700
# Running batch 38400
# Running batch 66500
# Running batch 50300
# Running batch 54700
# Running batch 60500
# Running batch 74000
# Running batch 56200
# Running batch 68100
# Running batch 53300
# Running batch 69500
# Running batch 39900
# Running batch 65100
# Running batch 59100
# Running batch 45900
# Running batch 44400
# Running batch 63600
# Running batch 41400
# Running batch 51800
# Running batch 72500
# Running batch 42900
# Running batch 48800
# Running batch 47400
# Running batch 57800
# Running batch 62100
# Running batch 50400
# Running batch 71100
# Running batch 38500
# Running batch 60600
# Running batch 56300
# Running batch 74100
# Running batch 68200
# Running batch 54800
# Running batch 66600
# Running batch 40000
# Running batch 69600
# Running batch 44500
# Running batch 46000
# Running batch 53400
# Running batch 63700
# Running batch 65200
# Running batch 41500
# Running batch 51900
# Running batch 59200
# Running batch 43000
# Running batch 62200
# Running batch 57900
# Running batch 71200
# Running batch 72600
# Running batch 38600
# Running batch 50500
# Running batch 47500
# Running batch 60700
# Running batch 48900
# Running batch 54900
# Running batch 40100
# Running batch 56400
# Running batch 74200
# Running batch 68300
# Running batch 46100
# Running batch 44600
# Running batch 69700
# Running batch 66700
# Running batch 53500
# Running batch 41600
# Running batch 63800
# Running batch 52000
# Running batch 65300
# Running batch 43100
# Running batch 59300
# Running batch 38700
# Running batch 58000
# Running batch 50600
# Running batch 47600
# Running batch 40200
# Running batch 56500
# Running batch 49000
# Running batch 74300
# Running batch 55000
# Running batch 46200
# Running batch 62300
# Running batch 72700
# Running batch 60800
# Running batch 71300
# Running batch 69800
# Running batch 53600
# Running batch 44700
# Running batch 41700
# Running batch 65400
# Running batch 52100
# Running batch 43200
# Running batch 68400
# Running batch 38800
# Running batch 58100
# Running batch 63900
# Running batch 59400
# Running batch 66800
# Running batch 47700
# Running batch 40300
# Running batch 50700
# Running batch 56600
# Running batch 46300
# Running batch 74400
# Running batch 62400
# Running batch 72800
# Running batch 60900
# Running batch 49100
# Running batch 53700
# Running batch 44800
# Running batch 41800
# Running batch 52200
# Running batch 71400
# Running batch 55100
# Running batch 68500
# Running batch 69900
# Running batch 65500
# Running batch 38900
# Running batch 58200
# Running batch 43300
# Running batch 47800
# Running batch 66900
# Running batch 40400
# Running batch 50800
# Running batch 59500
# Running batch 46400
# Running batch 64000
# Running batch 56700
# Running batch 61000
# Running batch 53800
# Running batch 41900
# Running batch 72900
# Running batch 44900
# Running batch 74500
# Running batch 49200
# Running batch 62500
# Running batch 75000
# Running batch 65600
# Running batch 52300
# Running batch 43400
# Running batch 68600
# Running batch 47900
# Running batch 70000
# Running batch 67000
# Running batch 55200
# Running batch 71500
# Running batch 58300
# Running batch 76500
# Running batch 78000
# Running batch 50900
# Running batch 56800
# Running batch 59600
# Running batch 53900
# Running batch 61100
# Running batch 79500
# Running batch 75100
# Running batch 64100
# Running batch 73000
# Running batch 81000
# Running batch 82500
# Running batch 74600
# Running batch 84000
# Running batch 62600
# Running batch 49300
# Running batch 68700
# Running batch 52400
# Running batch 55300
# Running batch 67100
# Running batch 58400
# Running batch 65700
# Running batch 70100
# Running batch 76600
# Running batch 85500
# Running batch 71600
# Running batch 56900
# Running batch 78100
# Running batch 87000
# Running batch 59700
# Running batch 79600
# Running batch 75200
# Running batch 81100
# Running batch 61200
# Running batch 82600
# Running batch 67200
# Running batch 84100
# Running batch 68800
# Running batch 62700
# Running batch 88500
# Running batch 74700
# Running batch 49400
# Running batch 65800
# Running batch 76700
# Running batch 55400
# Running batch 90000
# Running batch 85600
# Running batch 73100
# Running batch 64200
# Running batch 91500
# Running batch 78200
# Running batch 71700
# Running batch 87100
# Running batch 79700
# Running batch 70200
# Running batch 75300
# Running batch 81200
# Running batch 82700
# Running batch 59800
# Running batch 88600
# Running batch 84200
# Running batch 61300
# Running batch 67300
# Running batch 76800
# Running batch 85700
# Running batch 68900
# Running batch 90100
# Running batch 62800
# Running batch 91600
# Running batch 74800
# Running batch 87200
# Running batch 71800
# Running batch 65900
# Running batch 93000
# Running batch 78300
# Running batch 94500
# Running batch 73200
# Running batch 70300
# Running batch 75400
# Running batch 79800
# Running batch 81300
# Running batch 64300
# Running batch 88700
# Running batch 82800
# Running batch 84300
# Running batch 76900
# Running batch 61400
# Running batch 67400
# Running batch 85800
# Running batch 59900
# Running batch 90200
# Running batch 91700
# Running batch 87300
# Running batch 78400
# Running batch 71900
# Running batch 70400
# Running batch 62900
# Running batch 96000
# Running batch 75500
# Running batch 93100
# Running batch 81400
# Running batch 74900
# Running batch 94600
# Running batch 97500
# Running batch 79900
# Running batch 88800
# Running batch 73300
# Running batch 64400
# Running batch 82900
# Running batch 84400
# Running batch 85900
# Running batch 99000
# Running batch 77000
# Running batch 91800
# Running batch 90300
# Running batch 75600
# Running batch 78500
# Running batch 87400
# Running batch 100500
# Running batch 102000
# Running batch 103500
# Running batch 105000
# Running batch 81500
# Running batch 88900
# Running batch 80000
# Running batch 96100
# Running batch 93200
# Running batch 106500
# Running batch 83000
# Running batch 97600
# Running batch 108000
# Running batch 73400
# Running batch 94700
# Running batch 109500
# Running batch 84500
# Running batch 86000
# Running batch 77100
# Running batch 99100
# Running batch 75700
# Running batch 78600
# Running batch 87500
# Running batch 90400
# Running batch 91900
# Running batch 102100
# Running batch 89000
# Running batch 81600
# Running batch 105100
# Running batch 80100
# Running batch 93300
# Running batch 106600
# Running batch 96200
# Running batch 100600
# Running batch 97700
# Running batch 84600
# Running batch 83100
# Running batch 103600
# Running batch 77200
# Running batch 75800
# Running batch 99200
# Running batch 86100
# Running batch 94800
# Running batch 111000
# Running batch 87600
# Running batch 78700
# Running batch 108100
# Running batch 90500
# Running batch 109600
# Running batch 89100
# Running batch 92000
# Running batch 81700
# Running batch 105200
# Running batch 102200
# Running batch 80200
# Running batch 93400
# Running batch 96300
# Running batch 106700
# Running batch 84700
# Running batch 83200
# Running batch 77300
# Running batch 75900
# Running batch 97800
# Running batch 86200
# Running batch 99300
# Running batch 87700
# Running batch 89200
# Running batch 90600
# Running batch 111100
# Running batch 78800
# Running batch 81800
# Running batch 100700
# Running batch 103700
# Running batch 109700
# Running batch 108200
# Running batch 80300
# Running batch 105300
# Running batch 92100
# Running batch 93500
# Running batch 96400
# Running batch 94900
# Running batch 84800
# Running batch 76000
# Running batch 77400
# Running batch 83300
# Running batch 102300
# Running batch 87800
# Running batch 106800
# Running batch 89300
# Running batch 86300
# Running batch 99400
# Running batch 90700
# Running batch 78900
# Running batch 81900
# Running batch 111200
# Running batch 97900
# Running batch 103800
# Running batch 100800
# Running batch 108300
# Running batch 80400
# Running batch 105400
# Running batch 93600
# Running batch 76100
# Running batch 92200
# Running batch 109800
# Running batch 77500
# Running batch 83400
# Running batch 96500
# Running batch 84900
# Running batch 89400
# Running batch 87900
# Running batch 86400
# Running batch 79000
# Running batch 90800
# Running batch 99500
# Running batch 82000
# Running batch 102400
# Running batch 106900
# Running batch 95000
# Running batch 98000
# Running batch 105500
# Running batch 93700
# Running batch 108400
# Running batch 80500
# Running batch 76200
# Running batch 77600
# Running batch 83500
# Running batch 103900
# Running batch 92300
# Running batch 109900
# Running batch 89500
# Running batch 111300
# Running batch 88000
# Running batch 96600
# Running batch 86500
# Running batch 100900
# Running batch 79100
# Running batch 85000
# Running batch 82100
# Running batch 90900
# Running batch 102500
# Running batch 99600
# Running batch 76300
# Running batch 80600
# Running batch 107000
# Running batch 77700
# Running batch 108500
# Running batch 95100
# Running batch 83600
# Running batch 89600
# Running batch 93800
# Running batch 88100
# Running batch 104000
# Running batch 92400
# Running batch 105600
# Running batch 98100
# Running batch 86600
# Running batch 96700
# Running batch 79200
# Running batch 82200
# Running batch 101000
# Running batch 111400
# Running batch 85100
# Running batch 110000
# Running batch 91000
# Running batch 102600
# Running batch 76400
# Running batch 77800
# Running batch 99700
# Running batch 80700
# Running batch 89700
# Running batch 83700
# Running batch 93900
# Running batch 88200
# Running batch 107100
# Running batch 96800
# Running batch 86700
# Running batch 95200
# Running batch 108600
# Running batch 104100
# Running batch 79300
# Running batch 82300
# Running batch 92500
# Running batch 101100
# Running batch 105700
# Running batch 91100
# Running batch 112500
# Running batch 85200
# Running batch 77900
# Running batch 110100
# Running batch 89800
# Running batch 80800
# Running batch 111500
# Running batch 98200
# Running batch 83800
# Running batch 102700
# Running batch 99800
# Running batch 88300
# Running batch 96900
# Running batch 107200
# Running batch 86800
# Running batch 79400
# Running batch 95300
# Running batch 94000
# Running batch 82400
# Running batch 108700
# Running batch 92600
# Running batch 112600
# Running batch 91200
# Running batch 114000
# Running batch 101200
# Running batch 89900
# Running batch 104200
# Running batch 110200
# Running batch 85300
# Running batch 83900
# Running batch 80900
# Running batch 111600
# Running batch 105800
# Running batch 102800
# Running batch 88400
# Running batch 86900
# Running batch 99900
# Running batch 115500
# Running batch 117000
# Running batch 98300
# Running batch 97000
# Running batch 92700
# Running batch 112700
# Running batch 94100
# Running batch 107300
# Running batch 114100
# Running batch 108800
# Running batch 95400
# Running batch 118500
# Running batch 110300
# Running batch 91300
# Running batch 120000
# Running batch 121500
# Running batch 85400
# Running batch 123000
# Running batch 105900
# Running batch 102900
# Running batch 104300
# Running batch 101300
# Running batch 115600
# Running batch 124500
# Running batch 117100
# Running batch 100000
# Running batch 111700
# Running batch 98400
# Running batch 92800
# Running batch 112800
# Running batch 118600
# Running batch 94200
# Running batch 114200
# Running batch 108900
# Running batch 95500
# Running batch 91400
# Running batch 97100
# Running batch 110400
# Running batch 120100
# Running batch 121600
# Running batch 126000
# Running batch 107400
# Running batch 104400
# Running batch 124600
# Running batch 123100
# Running batch 115700
# Running batch 117200
# Running batch 106000
# Running batch 111800
# Running batch 112900
# Running batch 92900
# Running batch 118700
# Running batch 100100
# Running batch 103000
# Running batch 101400
# Running batch 114300
# Running batch 98500
# Running batch 127500
# Running batch 109000
# Running batch 121700
# Running batch 120200
# Running batch 110500
# Running batch 95600
# Running batch 94300
# Running batch 126100
# Running batch 124700
# Running batch 115800
# Running batch 104500
# Running batch 117300
# Running batch 107500
# Running batch 113000
# Running batch 118800
# Running batch 97200
# Running batch 114400
# Running batch 100200
# Running batch 123200
# Running batch 106100
# Running batch 127600
# Running batch 121800
# Running batch 120300
# Running batch 111900
# Running batch 101500
# Running batch 95700
# Running batch 129000
# Running batch 103100
# Running batch 94400
# Running batch 124800
# Running batch 115900
# Running batch 110600
# Running batch 98600
# Running batch 117400
# Running batch 109100
# Running batch 126200
# Running batch 104600
# Running batch 113100
# Running batch 107600
# Running batch 118900
# Running batch 114500
# Running batch 100300
# Running batch 97300
# Running batch 123300
# Running batch 127700
# Running batch 120400
# Running batch 121900
# Running batch 101600
# Running batch 106200
# Running batch 103200
# Running batch 117500
# Running batch 98700
# Running batch 116000
# Running batch 130500
# Running batch 113200
# Running batch 119000
# Running batch 124900
# Running batch 110700
# Running batch 112000
# Running batch 95800
# Running batch 109200
# Running batch 129100
# Running batch 126300
# Running batch 114600
# Running batch 107700
# Running batch 97400
# Running batch 123400
# Running batch 100400
# Running batch 104700
# Running batch 122000
# Running batch 120500
# Running batch 127800
# Running batch 101700
# Running batch 117600
# Running batch 113300
# Running batch 119100
# Running batch 125000
# Running batch 116100
# Running batch 106300
# Running batch 98800
# Running batch 110800
# Running batch 114700
# Running batch 109300
# Running batch 103300
# Running batch 130600
# Running batch 123500
# Running batch 126400
# Running batch 95900
# Running batch 132000
# Running batch 122100
# Running batch 129200
# Running batch 104800
# Running batch 107800
# Running batch 127900
# Running batch 101800
# Running batch 112100
# Running batch 133500
# Running batch 120600
# Running batch 119200
# Running batch 117700
# Running batch 125100
# Running batch 113400
# Running batch 116200
# Running batch 114800
# Running batch 109400
# Running batch 110900
# Running batch 123600
# Running batch 130700
# Running batch 122200
# Running batch 103400
# Running batch 126500
# Running batch 132100
# Running batch 107900
# Running batch 120700
# Running batch 128000
# Running batch 101900
# Running batch 129300
# Running batch 104900
# Running batch 106400
# Running batch 125200
# Running batch 98900
# Running batch 113500
# Running batch 135000
# Running batch 117800
# Running batch 112200
# Running batch 133600
# Running batch 119300
# Running batch 114900
# Running batch 116300
# Running batch 123700
# Running batch 122300
# Running batch 136500
# Running batch 126600
# Running batch 138000
# Running batch 120800
# Running batch 128100
# Running batch 129400
# Running batch 132200
# Running batch 113600
# Running batch 125300
# Running batch 130800
# Running batch 139500
# Running batch 135100
# Running batch 141000
# Running batch 117900
# Running batch 142500
# Running batch 144000
# Running batch 145500
# Running batch 119400
# Running batch 147000
# Running batch 112300
# Running batch 133700
# Running batch 115000
# Running batch 116400
# Running batch 123800
# Running batch 120900
# Running batch 138100
# Running batch 122400
# Running batch 129500
# Running batch 128200
# Running batch 125400
# Running batch 113700
# Running batch 126700
# Running batch 139600
# Running batch 118000
# Running batch 136600
# Running batch 130900
# Running batch 119500
# Running batch 144100
# Running batch 142600
# Running batch 135200
# Running batch 132300
# Running batch 141100
# Running batch 115100
# Running batch 145600
# Running batch 116500
# Running batch 133800
# Running batch 123900
# Running batch 147100
# Running batch 112400
# Running batch 121000
# Running batch 122500
# Running batch 129600
# Running batch 125500
# Running batch 113800
# Running batch 138200
# Running batch 128300
# Running batch 126800
# Running batch 118100
# Running batch 139700
# Running batch 131000
# Running batch 135300
# Running batch 142700
# Running batch 136700
# Running batch 119600
# Running batch 115200
# Running batch 116600
# Running batch 141200
# Running batch 145700
# Running batch 147200
# Running batch 124000
# Running batch 144200
# Running batch 132400
# Running batch 122600
# Running batch 121100
# Running batch 129700
# Running batch 125600
# Running batch 113900
# Running batch 133900
# Running batch 128400
# Running batch 126900
# Running batch 118200
# Running batch 139800
# Running batch 136800
# Running batch 148500
# Running batch 131100
# Running batch 115300
# Running batch 116700
# Running batch 119700
# Running batch 135400
# Running batch 124100
# Running batch 138300
# Running batch 141300
# Running batch 145800
# Running batch 121200
# Running batch 132500
# Running batch 147300
# Running batch 122700
# Running batch 125700
# Running batch 142800
# Running batch 129800
# Running batch 144300
# Running batch 128500
# Running batch 127000
# Running batch 134000
# Running batch 118300
# Running batch 139900
# Running batch 115400
# Running batch 148600
# Running batch 116800
# Running batch 119800
# Running batch 135500
# Running batch 136900
# Running batch 124200
# Running batch 121300
# Running batch 132600
# Running batch 145900
# Running batch 125800
# Running batch 147400
# Running batch 122800
# Running batch 128600
# Running batch 131200
# Running batch 127100
# Running batch 142900
# Running batch 129900
# Running batch 118400
# Running batch 138400
# Running batch 144400
# Running batch 134100
# Running batch 141400
# Running batch 140000
# Running batch 116900
# Running batch 119900
# Running batch 148700
# Running batch 124300
# Running batch 137000
# Running batch 125900
# Running batch 122900
# Running batch 121400
# Running batch 147500
# Running batch 132700
# Running batch 146000
# Running batch 131300
# Running batch 127200
# Running batch 128700
# Running batch 135600
# Running batch 143000
# Running batch 134200
# Running batch 141500
# Running batch 138500
# Running batch 140100
# Running batch 124400
# Running batch 130000
# Running batch 144500
# Running batch 148800
# Running batch 147600
# Running batch 137100
# Running batch 146100
# Running batch 131400
# Running batch 127300
# Running batch 128800
# Running batch 132800
# Running batch 143100
# Running batch 135700
# Running batch 134300
# Running batch 138600
# Running batch 140200
# Running batch 141600
# Running batch 130100
# Running batch 148900
# Running batch 144600
# Running batch 147700
# Running batch 137200
# Running batch 146200
# Running batch 127400
# Running batch 131500
# Running batch 128900
# Running batch 132900
# Running batch 134400
# Running batch 143200
# Running batch 135800
# Running batch 138700
# Running batch 130200
# Running batch 141700
# Running batch 140300
# Running batch 149000
# Running batch 144700
# Running batch 147800
# Running batch 137300
# Running batch 131600
# Running batch 146300
# Running batch 134500
# Running batch 143300
# Running batch 133000
# Running batch 135900
# Running batch 138800
# Running batch 140400
# Running batch 141800
# Running batch 130300
# Running batch 149100
# Running batch 144800
# Running batch 137400
# Running batch 131700
# Running batch 147900
# Running batch 146400
# Running batch 134600
# Running batch 143400
# Running batch 133100
# Running batch 138900
# Running batch 140500
# Running batch 141900
# Running batch 149200
# Running batch 130400
# Running batch 144900
# Running batch 136000
# Running batch 137500
# Running batch 146500
# Running batch 134700
# Running batch 131800
# Running batch 143500
# Running batch 148000
# Running batch 133200
# Running batch 139000
# Running batch 140600
# Running batch 142000
# Running batch 149300
# Running batch 137600
# Running batch 145000
# Running batch 136100
# Running batch 134800
# Running batch 146600
# Running batch 143600
# Running batch 148100
# Running batch 131900
# Running batch 133300
# Running batch 139100
# Running batch 140700
# Running batch 149400
# Running batch 142100
# Running batch 137700
# Running batch 145100
# Running batch 136200
# Running batch 134900
# Running batch 143700
# Running batch 146700
# Running batch 148200
# Running batch 133400
# Running batch 139200
# Running batch 149500
# Running batch 140800
# Running batch 142200
# Running batch 137800
# Running batch 145200
# Running batch 136300
# Running batch 143800
# Running batch 146800
# Running batch 148300
# Running batch 139300
# Running batch 149600
# Running batch 140900
# Running batch 137900
# Running batch 142300
# Running batch 145300
# Running batch 136400
# Running batch 143900
# Running batch 148400
# Running batch 146900
# Running batch 139400
# Running batch 149700
# Running batch 142400
# Running batch 145400
# Running batch 149800
# Running batch 149900

# %% [markdown]
# # Train RNN first on a subset of tasks (half the tasks) using CPU

# %%
model = reload(model)
input_batches, output_batches = model.load_training_batches(cuda=False)
test_inputs, test_outputs = model.load_testset(cuda=False)

# %%
model = reload(model)
Network = model.RNN(num_rule_inputs=12,
                     num_sensory_inputs=16,
                     num_hidden=128,
                     num_motor_decision_outputs=4,
                     learning_rate=0.0001,
                     thresh=0.9)
# Network.cuda = True
Network = Network.cpu()

# %%
model = reload(model) 
timestart = time.time()
model.batch_training(Network, input_batches,output_batches,cuda=False)  
timeend = time.time()
print 'Time elapsed using CPU:', timeend-timestart
# Out:
# Iteration: 0
# 	loss: 0.253582566977
# Time elapsed... 0.0115549564362
# 	Accuracy: 0.0%
# Iteration: 5000
# 	loss: 0.0899647250772
# Time elapsed... 11.0452830791
# 	Accuracy: 0.0%
# Iteration: 10000
# 	loss: 0.0598498694599
# Time elapsed... 11.691521883
# 	Accuracy: 8.3333%
# Iteration: 15000
# 	loss: 0.0687529146671
# Time elapsed... 12.3160851002
# 	Accuracy: 29.1667%
# Iteration: 20000
# 	loss: 0.0398500859737
# Time elapsed... 10.9046399593
# 	Accuracy: 31.25%
# Iteration: 25000
# 	loss: 0.0239020306617
# Time elapsed... 10.999475956
# 	Accuracy: 58.3333%
# Iteration: 30000
# 	loss: 0.00815108790994
# Time elapsed... 10.4091379642
# 	Accuracy: 68.75%
# Iteration: 35000
# 	loss: 0.00138975447044
# Time elapsed... 10.4073472023
# 	Accuracy: 95.8333%
# Iteration: 40000
# 	loss: 0.00036781351082
# Time elapsed... 11.4844689369
# 	Accuracy: 97.9167%
# Iteration: 45000
# 	loss: 0.000203750460059
# Time elapsed... 11.3463718891
# 	Accuracy: 100.0%
# Iteration: 50000
# 	loss: 5.77190912736e-05
# Time elapsed... 11.5179691315
# 	Accuracy: 100.0%
# Last 1000 batches had above 99.5% accuracy... stopping training
# Time elapsed using CPU: 112.144024849

# %% [markdown]
# # Test on held-out tasks

# %%
model = reload(model)
outputs, hidden = model.eval(Network,test_inputs,test_outputs,cuda=False)
# Out:
# 	loss: 0.100028008223
# 	Accuracy: 37.5%

# %% [markdown]
# # Plot example miniblocks

# %%
outputs2 = outputs.detach().numpy()
hidden2 = hidden.detach().numpy()
inputs2 = test_inputs.detach().numpy()

# %%
plt.figure(figsize=(10,5))
plt.title('Input sequence',fontsize=24)
plt.ylabel('Input',fontsize=20)
plt.xlabel('Time',fontsize=20)
a = sns.heatmap(inputs2[:,0,:].T,cmap='Blues')
a.invert_yaxis()

plt.figure(figsize=(10,5))
plt.title('Hidden unit activity',fontsize=24)
plt.ylabel('Input',fontsize=20)
plt.xlabel('Time',fontsize=20)
a = sns.heatmap(hidden2[:,0,:].T,cmap='Blues')
a.invert_yaxis()

plt.figure(figsize=(10,5))
plt.title('Output unit activity',fontsize=24)
plt.ylabel('Input',fontsize=20)
plt.xlabel('Time',fontsize=20)
a = sns.heatmap(outputs2[:,0,:].T,cmap='Blues')
a.invert_yaxis()

# %% [markdown]
# # Simulate spontaneous activity on network

# %%
model = reload(model)
ntps = 1000
runs = 1
input_dim = 28
rest_time = torch.empty(ntps, runs, input_dim)
output_dummy = torch.empty(ntps, runs, 4) # output dummy variable, rest so everything is 0
rest_output, rest_hidden = model.eval(Network,rest_time,output_dummy,cuda=False)

rest_output = np.squeeze(rest_output.detach().numpy())
rest_hidden = np.squeeze(rest_hidden.detach().numpy())

# %%
plt.figure(figsize=(10,5))
plt.title('Simulated random activity', fontsize=20)
ax = sns.heatmap(rest_hidden.T,cmap='Blues')
ax.invert_yaxis()
plt.xlabel('Time',fontsize=18)
plt.ylabel('Units',fontsize=18)

# Construct correlation matrix
corrmat = np.corrcoef(rest_hidden.T)
sig = np.multiply(corrmat,corrmat>0)
ci, q = bct.community_louvain(sig)
networkdef = sorted(range(len(ci)), key=lambda k: ci[k])
networkdef = np.asarray(networkdef)
networkdef.shape = (len(networkdef),1)

plt.figure()
ax = sns.heatmap(corrmat[networkdef,networkdef.T],square=True,center=0,cmap='bwr')
ax.invert_yaxis()
plt.title('Correlation matrix',fontsize=24,y=1.04)
plt.xlabel('Regions',fontsize=20)
plt.ylabel('Regions',fontsize=20)
# plt.savefig('NoiseInduced_CorrelationMatrix.pdf')

# %% [markdown]
# ## Analyze recurrent connectivity weights

# %%
mat = Network.weight_hh_l0.detach().numpy()
plt.figure()
ax = sns.heatmap(mat[networkdef,networkdef.T],square=True,center=0,cmap='bwr')
ax.invert_yaxis()
plt.title('Recurrent connectivity weights',fontsize=24,y=1.04)
plt.xlabel('Regions',fontsize=20)
plt.ylabel('Regions',fontsize=20)
plt.tight_layout()
# plt.savefig('GroundTruth_RNN_weights.pdf')

# %%
mat = Network.weight_hh_l0.detach().numpy()
plt.figure()
ax = sns.heatmap(mat,square=True,center=0,cmap='bwr')
ax.invert_yaxis()
plt.title('Recurrent connectivity weights',fontsize=24,y=1.04)
plt.xlabel('Regions',fontsize=20)
plt.ylabel('Regions',fontsize=20)
plt.tight_layout()
# plt.savefig('GroundTruth_RNN_weights.pdf')
