# %% [markdown]
# # fMRI6a -- Compute the actflow decodability of Motor responses (LINDEX v. LMID and RINDEX v. RMID)
# ## Using EigenActFlow using PCA regression
# # Within subjects
#
# ## Takuya Ito
# #### 2/22/2019

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import multiprocessing as mp
import scipy.stats as stats
import nibabel as nib
import os
os.environ['OMP_NUM_THREADS'] = str(1)
import statsmodels.api as sm
import sklearn.svm as svm
import statsmodels.sandbox.stats.multicomp as mc
import sklearn
from sklearn.feature_selection import f_classif
import seaborn as sns
import h5py
os.sys.path.append('glmScripts/')
import taskGLMPipeline as tgp
import statsmodels.api as sm
import sys
sys.path.append('utils/')
import loadExperimentalData as led
import tools

sns.set_style("whitegrid")
plt.rcParams["font.family"] = "FreeSans"

# %%
# Excluding 084
subjNums = ['013','014','016','017','018','021','023','024','026','027','028','030','031','032','033',
            '034','035','037','038','039','040','041','042','043','045','046','047','048','049','050',
            '053','055','056','057','058','062','063','066','067','068','069','070','072','074','075',
            '076','077','081','085','086','087','088','090','092','093','094','095','097','098','099',
            '101','102','103','104','105','106','108','109','110','111','112','114','115','117','119',
            '120','121','122','123','124','125','126','127','128','129','130','131','132','134','135',
            '136','137','138','139','140','141']

basedir = '/projects3/SRActFlow/'

# Using final partition
networkdef = np.loadtxt('/projects3/NetworkDiversity/data/network_partition.txt')
networkorder = np.asarray(sorted(range(len(networkdef)), key=lambda k: networkdef[k]))
networkorder.shape = (len(networkorder),1)
# network mappings for final partition set
networkmappings = {'fpn':7, 'vis1':1, 'vis2':2, 'smn':3, 'aud':8, 'lan':6, 'dan':5, 'con':4, 'dmn':9, 
                   'pmulti':10, 'none1':11, 'none2':12}
networks = networkmappings.keys()

xticks = {}
reorderednetworkaffil = networkdef[networkorder]
for net in networks:
    netNum = networkmappings[net]
    netind = np.where(reorderednetworkaffil==netNum)[0]
    tick = np.max(netind)
    xticks[tick] = net

## General parameters/variables
nParcels = 360
nSubjs = len(subjNums)

glasserfile2 = '/projects/AnalysisTools/ParcelsGlasser2016/Q1-Q6_RelatedParcellation210.LR.CorticalAreas_dil_Colors.32k_fs_RL.dlabel.nii'
glasser2 = nib.load(glasserfile2).get_data()
glasser2 = np.squeeze(glasser2)

sortednets = np.sort(xticks.keys())
orderednetworks = []
for net in sortednets: orderednetworks.append(xticks[net])
    
networkpalette = ['royalblue','slateblue','paleturquoise','darkorchid','limegreen',
                  'lightseagreen','yellow','orchid','r','peru','orange','olivedrab']
networkpalette = np.asarray(networkpalette)

OrderedNetworks = ['VIS1','VIS2','SMN','CON','DAN','LAN','FPN','AUD','DMN','PMM','VMM','ORA']

# %% [markdown]
# # 0.0 Define functions for loading data

# %% [markdown]
# ## 0.1 Load data

# %%
tools = reload(tools)

# %%
# gsr = True
nTrials = 384
data_task = np.zeros((len(glasser2),nTrials,len(subjNums)))

scount = 0
for subj in subjNums:
    if scount%4==0: print 'Loading subject', scount, '/', len(subjNums)
    data_task[:,:,scount] = tools.loadMotorResponses(subj)
    scount += 1
# Out:
# Loading subject 0 / 96
# Loading subject 4 / 96
# Loading subject 8 / 96
# Loading subject 12 / 96
# Loading subject 16 / 96
# Loading subject 20 / 96
# Loading subject 24 / 96
# Loading subject 28 / 96
# Loading subject 32 / 96
# Loading subject 36 / 96
# Loading subject 40 / 96
# Loading subject 44 / 96
# Loading subject 48 / 96
# Loading subject 52 / 96
# Loading subject 56 / 96
# Loading subject 60 / 96
# Loading subject 64 / 96
# Loading subject 68 / 96
# Loading subject 72 / 96
# Loading subject 76 / 96
# Loading subject 80 / 96
# Loading subject 84 / 96
# Loading subject 88 / 96
# Loading subject 92 / 96

# %% [markdown]
# # 1.0 Define functions for motor response decodings

# %% [markdown]
# ## 1.1 Run actflow and decoding analyses

# %%
tools = reload(tools)

# %%
nproc = 20
n_components_include = 100
ncvs = 10

roi_rh = 9
roi_lh = 189
# roi_rh = 8
# roi_lh = 188

roi_rh_ind = np.where(glasser2==roi_rh)[0]
roi_lh_ind = np.where(glasser2==roi_lh)[0]

actflow_data_rh = np.zeros((len(roi_rh_ind),data_task.shape[1],len(subjNums))) # n vertices for target region, n miniblocks, n source regions, n subjects
actflow_data_lh = np.zeros((len(roi_lh_ind),data_task.shape[1],len(subjNums)))

dilateLH = tools.loadMask(roi_lh,dilated=True)
dilateRH = tools.loadMask(roi_rh,dilated=True)
combinedDilated = dilateLH + dilateRH
# combinedDilated = dilateRH
# Exclude all SMN regions
smn_rois = np.where(networkdef==networkmappings['smn'])[0]
for x in smn_rois:
    roi_ind = np.where(glasser2==x)[0]
    combinedDilated[roi_ind]=1
source_ind = np.where(combinedDilated==0)[0]

accuracies_rh = np.zeros((1,len(subjNums)))
accuracies_lh = np.zeros((1,len(subjNums)))

scount = 0
for subj in subjNums:
    print 'Run analysis for subject', subj, '(', scount + 1, '/', len(subjNums), ')'
    print '\tLoad PCA_FC...'
    fcmapping_rh = tools.loadPcaFCNoColliders(subj,roi_rh)
    fcmapping_lh = tools.loadPcaFCNoColliders(subj,roi_lh)
    
    inputs_lh = []
    inputs_rh = []
        
    print '\tPerform actflow in brain space...'
    # Right Finger 1
    actflow_data_rh[:,:,scount] = np.dot(data_task[source_ind,:,scount].T,fcmapping_rh).T
    # Right Finger 2:
    actflow_data_lh[:,:,scount] = np.dot(data_task[source_ind,:,scount].T,fcmapping_lh).T
#     # Right Finger 1
#     actflow_data_rh[:,:,scount] = np.dot(stats.zscore(data_task[source_ind,:,scount],axis=0).T,fcmapping_rh).T
#     # Right Finger 2:
#     actflow_data_lh[:,:,scount] = np.dot(stats.zscore(data_task[source_ind,:,scount],axis=0).T,fcmapping_lh).T
    
    # Gather real target data
    data_rh = stats.zscore(data_task[roi_rh_ind,:,scount],axis=0)
    data_lh = stats.zscore(data_task[roi_lh_ind,:,scount],axis=0)
#     data_rh = data_task[roi_rh_ind,:,scount]
#     data_lh = data_task[roi_lh_ind,:,scount]
#     actflow_data_rh[:,:,scount] = stats.zscore(actflow_data_rh[:,:,scount],axis=0)
#     actflow_data_lh[:,:,scount] = stats.zscore(actflow_data_lh[:,:,scount],axis=0)
        
    accuracies_rh[0,scount] = tools.motorResponseDecodings((data_rh,actflow_data_rh[:,:,scount],subj,'right',ncvs))
    accuracies_lh[0,scount] = tools.motorResponseDecodings((data_lh,actflow_data_lh[:,:,scount],subj,'left',ncvs))
    
    scount += 1
# Out:
# Run analysis for subject 013 ( 1 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 014 ( 2 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 016 ( 3 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 017 ( 4 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 018 ( 5 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 021 ( 6 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 023 ( 7 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 024 ( 8 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 026 ( 9 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 027 ( 10 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 028 ( 11 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 030 ( 12 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 031 ( 13 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 032 ( 14 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 033 ( 15 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 034 ( 16 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 035 ( 17 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 037 ( 18 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 038 ( 19 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 039 ( 20 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 040 ( 21 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 041 ( 22 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 042 ( 23 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 043 ( 24 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 045 ( 25 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 046 ( 26 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 047 ( 27 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 048 ( 28 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 049 ( 29 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 050 ( 30 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 053 ( 31 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 055 ( 32 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 056 ( 33 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 057 ( 34 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 058 ( 35 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 062 ( 36 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 063 ( 37 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 066 ( 38 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 067 ( 39 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 068 ( 40 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 069 ( 41 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 070 ( 42 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 072 ( 43 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 074 ( 44 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 075 ( 45 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 076 ( 46 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 077 ( 47 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 081 ( 48 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 085 ( 49 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 086 ( 50 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 087 ( 51 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 088 ( 52 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 090 ( 53 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 092 ( 54 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 093 ( 55 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 094 ( 56 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 095 ( 57 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 097 ( 58 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 098 ( 59 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 099 ( 60 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 101 ( 61 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 102 ( 62 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 103 ( 63 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 104 ( 64 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 105 ( 65 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 106 ( 66 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 108 ( 67 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 109 ( 68 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 110 ( 69 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 111 ( 70 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 112 ( 71 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 114 ( 72 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 115 ( 73 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 117 ( 74 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 119 ( 75 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 120 ( 76 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 121 ( 77 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 122 ( 78 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 123 ( 79 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 124 ( 80 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 125 ( 81 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 126 ( 82 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 127 ( 83 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 128 ( 84 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 129 ( 85 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 130 ( 86 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 131 ( 87 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 132 ( 88 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 134 ( 89 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 135 ( 90 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 136 ( 91 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 137 ( 92 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 138 ( 93 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 139 ( 94 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 140 ( 95 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...
# Run analysis for subject 141 ( 96 / 96 )
# 	Load PCA_FC...
# 	Perform actflow in brain space...

# %% [markdown]
# ## 1.2 Compute right-hand response statistics

# %%
statistics_rh = np.zeros((3,)) # acc, t, qs
ps = []
t, p = stats.ttest_1samp(accuracies_rh[0,:],0.5)
if t>0:
    p = p/2.0
else:
    p = 1.0-p/2.0
ps.append(p)
    
statistics_rh[0] = np.mean(accuracies_rh[0,:])
statistics_rh[1] = t
statistics_rh[2] = p

    
print '\tAccuracy:', statistics_rh[0]
print '\tP-value:', statistics_rh[2]
# Out:
# 	Accuracy: 0.507291666667
# 	P-value: 0.388087663711

# %% [markdown]
# ## 1.2 Compute left-hand response statistics

# %%
statistics_lh = np.zeros((3,)) # acc, t, qs
ps = []
t, p = stats.ttest_1samp(accuracies_lh[0,:],0.5)
if t>0:
    p = p/2.0
else:
    p = 1.0-p/2.0
ps.append(p)
    
statistics_lh[0] = np.mean(accuracies_lh[0,:])
statistics_lh[1] = t
statistics_lh[2] = p

    
print '\tAccuracy:', statistics_lh[0]
print '\tP-value:', statistics_lh[2]
# Out:
# 	Accuracy: 0.49375
# 	P-value: 0.594791858161
